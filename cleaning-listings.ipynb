# %%
import pandas as pd
pd.options.display.max_rows = 6000

listings = pd.read_csv('listings.csv')

# %%
# columns

[i for i in listings.columns]
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
# first 5 rows of listings

listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  18666  https://www.airbnb.com/rooms/18666  20190710134514   2019-07-10
# 1  18674  https://www.airbnb.com/rooms/18674  20190710134514   2019-07-10
# 2  21605  https://www.airbnb.com/rooms/21605  20190710134514   2019-07-10
# 3  23197  https://www.airbnb.com/rooms/23197  20190710134514   2019-07-10
# 4  25786  https://www.airbnb.com/rooms/25786  20190710134514   2019-07-10
#
#                                               name  \
# 0                          Flat with Sunny Terrace
# 1  Huge flat for 8 people close to Sagrada Familia
# 2                        Nice and sunny duble room
# 3     FORUM DELUXE 5 MINS WALK  CCIB CENTER & SEA!
# 4       NICE ROOM AVAILABLE IN THE HEART OF GRACIA
#
#                                              summary  \
# 0  Apartment located near the "Plaza de las Glori...
# 1  110m2 apartment to rent in Barcelona. Located ...
# 2  The flat is in Poblenou district, and the room...
# 3  I do not accept groups of young people under 2...
# 4  JUST GO THROUGH THE MANY REVIEWS I GOT THROUGH...
#
#                                                space  \
# 0  Nice apartment situated on the penthouse floor...
# 1  Apartment with 110 m2 located in the 6th floor...
# 2  L'apartament està al barri de Poblenou, i l'ha...
# 3  Elegant spacious apartment suitable for 6. Amp...
# 4  Room available for rent.-  PEDRO PEREZ.  Share...
#
#                                          description experiences_offered  \
# 0  Apartment located near the "Plaza de las Glori...                none
# 1  110m2 apartment to rent in Barcelona. Located ...                none
# 2  The flat is in Poblenou district, and the room...                none
# 3  I do not accept groups of young people under 2...                none
# 4  JUST GO THROUGH THE MANY REVIEWS I GOT THROUGH...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0  Apartment in Barcelona near to the Plaza de la...  ...                f
# 1  Apartment in Barcelona located in the heart of...  ...                t
# 2  Poblenou as one of the few areas that has grow...  ...                f
# 3  Strategically located in the area of Parc del ...  ...                t
# 4  Solo decir que a menudo ni salgo del barrio. M...  ...                t
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     flexible
# 1                        f  strict_14_with_grace_period
# 2                        f                     moderate
# 3                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                t
# 4                             t                                t
#
#    calculated_host_listings_count  \
# 0                              31
# 1                              31
# 2                               2
# 3                               2
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                           31
# 1                                           31
# 2                                            0
# 3                                            2
# 4                                            0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            2
# 3                                            0
# 4                                            1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.02
# 1                                            0               0.20
# 2                                            0               3.08
# 3                                            0               0.44
# 4                                            0               2.22
#
# [5 rows x 106 columns]

# %%
# determining missingness among columns

def missingness(df):
    return df.isna().sum().sort_values(ascending = False) / len(df) * 100

missingness(listings)
# Out:
# host_acceptance_rate                            100.000000
# xl_picture_url                                  100.000000
# medium_url                                      100.000000
# jurisdiction_names                              100.000000
# thumbnail_url                                   100.000000
# square_feet                                      97.357939
# weekly_price                                     93.409973
# monthly_price                                    92.633490
# notes                                            52.170625
# access                                           46.029345
# interaction                                      43.316694
# transit                                          39.701508
# license                                          38.456109
# host_about                                       35.909847
# neighborhood_overview                            34.256038
# house_rules                                      32.597187
# security_deposit                                 28.896284
# space                                            26.390360
# review_scores_checkin                            24.504614
# review_scores_location                           24.494529
# review_scores_value                              24.489487
# review_scores_accuracy                           24.479403
# review_scores_cleanliness                        24.479403
# review_scores_communication                      24.459235
# review_scores_rating                             24.439066
# reviews_per_month                                23.284425
# first_review                                     23.284425
# last_review                                      23.284425
# cleaning_fee                                     20.516311
# host_neighbourhood                               19.563354
# host_response_rate                               12.696012
# host_response_time                               12.696012
# summary                                           5.092523
# zipcode                                           3.045429
# state                                             2.510967
# description                                       1.820199
# host_location                                     0.292442
# host_thumbnail_url                                0.171431
# host_identity_verified                            0.171431
# host_has_profile_pic                              0.171431
# host_total_listings_count                         0.171431
# host_listings_count                               0.171431
# host_since                                        0.171431
# host_picture_url                                  0.171431
# beds                                              0.171431
# host_is_superhost                                 0.171431
# host_name                                         0.171431
# market                                            0.095800
# name                                              0.085716
# neighbourhood                                     0.050421
# bathrooms                                         0.045379
# city                                              0.020168
# bedrooms                                          0.015126
# street                                            0.000000
# listing_url                                       0.000000
# neighbourhood_group_cleansed                      0.000000
# neighbourhood_cleansed                            0.000000
# host_verifications                                0.000000
# last_scraped                                      0.000000
# host_id                                           0.000000
# picture_url                                       0.000000
# scrape_id                                         0.000000
# experiences_offered                               0.000000
# host_url                                          0.000000
# room_type                                         0.000000
# smart_location                                    0.000000
# maximum_nights_avg_ntm                            0.000000
# has_availability                                  0.000000
# availability_30                                   0.000000
# availability_60                                   0.000000
# availability_90                                   0.000000
# availability_365                                  0.000000
# calendar_last_scraped                             0.000000
# number_of_reviews                                 0.000000
# number_of_reviews_ltm                             0.000000
# requires_license                                  0.000000
# instant_bookable                                  0.000000
# is_business_travel_ready                          0.000000
# cancellation_policy                               0.000000
# require_guest_profile_picture                     0.000000
# require_guest_phone_verification                  0.000000
# calculated_host_listings_count                    0.000000
# calculated_host_listings_count_entire_homes       0.000000
# calculated_host_listings_count_private_rooms      0.000000
# calendar_updated                                  0.000000
# minimum_nights_avg_ntm                            0.000000
# country_code                                      0.000000
# maximum_maximum_nights                            0.000000
# country                                           0.000000
# latitude                                          0.000000
# longitude                                         0.000000
# is_location_exact                                 0.000000
# property_type                                     0.000000
# calculated_host_listings_count_shared_rooms       0.000000
# accommodates                                      0.000000
# bed_type                                          0.000000
# amenities                                         0.000000
# price                                             0.000000
# guests_included                                   0.000000
# extra_people                                      0.000000
# minimum_nights                                    0.000000
# maximum_nights                                    0.000000
# minimum_minimum_nights                            0.000000
# maximum_minimum_nights                            0.000000
# minimum_maximum_nights                            0.000000
# id                                                0.000000
# dtype: float64

# %%
# drop primarily missing columns

listings = listings.drop(columns = ['host_acceptance_rate', 'xl_picture_url', 'medium_url', 'jurisdiction_names', 'thumbnail_url', 'square_feet'])

# %%
# determining repeating columns

def repeating_cols(df):
    comparisons = []
    match_ratios = []
    
    for i in range(len(df.columns)):
        for j in range(i + 1, len(df.columns)):
            comparisons_i = [df.columns[i], df.columns[j]]
            comparisons.append(comparisons_i)
    
    for i in comparisons:
        match_ratios_i = [(df[i[0]] == df[i[1]]).sum() / len(df) * 100, i[0] + ' - ' + i[1]]
        match_ratios.append(match_ratios_i)
    match_ratios.sort(reverse = True)
    
    return match_ratios

repeating_cols(listings)
# Out:
# [[100.0, 'last_scraped - calendar_last_scraped'],
#  [100.0, 'has_availability - requires_license'],
#  [99.82856854737054, 'host_listings_count - host_total_listings_count'],
#  [99.61680028235769, 'host_has_profile_pic - requires_license'],
#  [99.61680028235769, 'host_has_profile_pic - has_availability'],
#  [98.63359048051228,
#   'is_business_travel_ready - require_guest_profile_picture'],
#  [98.44703272323905, 'maximum_nights - maximum_maximum_nights'],
#  [98.19996974739071, 'minimum_maximum_nights - maximum_nights_avg_ntm'],
#  [98.16467503655524, 'minimum_maximum_nights - maximum_maximum_nights'],
#  [98.16467503655524, 'maximum_maximum_nights - maximum_nights_avg_ntm'],
#  [97.53441234306459, 'maximum_nights - minimum_maximum_nights'],
#  [97.51424393687289,
#   'require_guest_profile_picture - require_guest_phone_verification'],
#  [97.23188625018908, 'maximum_nights - maximum_nights_avg_ntm'],
#  [96.86885493873847, 'city - market'],
#  [96.51086572883578,
#   'is_business_travel_ready - require_guest_phone_verification'],
#  [87.49558816114556, 'minimum_nights - minimum_minimum_nights'],
#  [81.16270861695153, 'host_is_superhost - is_business_travel_ready'],
#  [80.93581404729491, 'host_is_superhost - require_guest_profile_picture'],
#  [79.86688851913478, 'host_is_superhost - require_guest_phone_verification'],
#  [79.00973125598749, 'minimum_nights - maximum_minimum_nights'],
#  [77.7290374628145, 'minimum_nights - minimum_nights_avg_ntm'],
#  [76.09035445973882, 'maximum_minimum_nights - minimum_nights_avg_ntm'],
#  [74.92562900216811, 'minimum_minimum_nights - minimum_nights_avg_ntm'],
#  [73.06509353098372, 'minimum_minimum_nights - maximum_minimum_nights'],
#  [67.30701356325316, 'is_location_exact - requires_license'],
#  [67.30701356325316, 'is_location_exact - has_availability'],
#  [67.13054000907577,
#   'host_identity_verified - require_guest_phone_verification'],
#  [67.0952452982403, 'host_has_profile_pic - is_location_exact'],
#  [66.58599304189985, 'host_identity_verified - require_guest_profile_picture'],
#  [66.34901426914737, 'host_identity_verified - is_business_travel_ready'],
#  [65.4918570060001,
#   'host_total_listings_count - calculated_host_listings_count'],
#  [65.4918570060001, 'host_listings_count - calculated_host_listings_count'],
#  [64.82629960167398, 'host_is_superhost - host_identity_verified'],
#  [59.18418796954571, 'review_scores_checkin - review_scores_communication'],
#  [56.879947562143904, 'neighbourhood - neighbourhood_group_cleansed'],
#  [56.219432259365696, 'bedrooms - guests_included'],
#  [56.12867443150304, 'requires_license - instant_bookable'],
#  [56.12867443150304, 'has_availability - instant_bookable'],
#  [56.03791660364039, 'bedrooms - beds'],
#  [55.95724297887359, 'host_has_profile_pic - instant_bookable'],
#  [53.49165532193818, 'bathrooms - bedrooms'],
#  [52.54374023092825, 'review_scores_accuracy - review_scores_communication'],
#  [52.21600363031311, 'beds - guests_included'],
#  [51.752130287903995, 'review_scores_accuracy - review_scores_checkin'],
#  [50.542025916401954, 'number_of_reviews - number_of_reviews_ltm'],
#  [49.77562648111733, 'review_scores_communication - review_scores_location'],
#  [49.30166893561236, 'review_scores_accuracy - review_scores_cleanliness'],
#  [49.27141632632481, 'bathrooms - guests_included'],
#  [49.03947965512025, 'review_scores_checkin - review_scores_location'],
#  [48.64619573438209, 'is_location_exact - instant_bookable'],
#  [48.13190137649372, 'host_identity_verified - is_location_exact'],
#  [47.77895426813896,
#   'calculated_host_listings_count_entire_homes - calculated_host_listings_count_shared_rooms'],
#  [47.74870165885141,
#   'calculated_host_listings_count - calculated_host_listings_count_private_rooms'],
#  [46.2663238037614, 'review_scores_accuracy - review_scores_location'],
#  [44.74865123783593, 'host_is_superhost - instant_bookable'],
#  [44.44108304341249, 'review_scores_accuracy - review_scores_value'],
#  [44.37049362174154,
#   'review_scores_cleanliness - review_scores_communication'],
#  [44.309988403166436, 'review_scores_cleanliness - review_scores_checkin'],
#  [43.95199919326375, 'instant_bookable - require_guest_phone_verification'],
#  [43.87132556849695, 'instant_bookable - is_business_travel_ready'],
#  [43.81586245146977, 'review_scores_cleanliness - review_scores_value'],
#  [43.78560984218222,
#   'calculated_host_listings_count_private_rooms - calculated_host_listings_count_shared_rooms'],
#  [43.654515201936164,
#   'calculated_host_listings_count - calculated_host_listings_count_entire_homes'],
#  [43.57384157716936, 'instant_bookable - require_guest_profile_picture'],
#  [41.909948066354055, 'host_is_superhost - is_location_exact'],
#  [41.7183482075329, 'bathrooms - beds'],
#  [41.18892754500076, 'host_identity_verified - instant_bookable'],
#  [40.72505420259164, 'review_scores_cleanliness - review_scores_location'],
#  [39.580497151212626,
#   'host_total_listings_count - calculated_host_listings_count_private_rooms'],
#  [39.580497151212626,
#   'host_listings_count - calculated_host_listings_count_private_rooms'],
#  [36.595573034840925, 'review_scores_communication - review_scores_value'],
#  [35.8896788181314, 'review_scores_checkin - review_scores_value'],
#  [35.30479503857208, 'review_scores_location - review_scores_value'],
#  [35.113195179750925, 'is_location_exact - require_guest_phone_verification'],
#  [33.68123834014017, 'host_has_profile_pic - host_identity_verified'],
#  [33.61569102001714, 'is_location_exact - require_guest_profile_picture'],
#  [33.47955427822316, 'host_identity_verified - requires_license'],
#  [33.47955427822316, 'host_identity_verified - has_availability'],
#  [32.692986436746835, 'is_location_exact - is_business_travel_ready'],
#  [31.054303433671155,
#   'number_of_reviews_ltm - calculated_host_listings_count_shared_rooms'],
#  [29.551757172389454, 'guests_included - calculated_host_listings_count'],
#  [29.309736298089046, 'bathrooms - minimum_minimum_nights'],
#  [29.188725860938842, 'bathrooms - calculated_host_listings_count'],
#  [28.55342106590027, 'bedrooms - minimum_minimum_nights'],
#  [27.948368880149243, 'bedrooms - calculated_host_listings_count'],
#  [27.44920082690465, 'bedrooms - minimum_nights'],
#  [27.187011546412542, 'host_neighbourhood - neighbourhood'],
#  [26.869359148893256, 'accommodates - guests_included'],
#  [26.612211969949072, 'availability_90 - availability_365'],
#  [26.55170675137397, 'availability_60 - availability_90'],
#  [26.430696314223766,
#   'availability_30 - calculated_host_listings_count_shared_rooms'],
#  [26.420612111127916, 'beds - calculated_host_listings_count'],
#  [26.057580799677304, 'host_total_listings_count - guests_included'],
#  [26.057580799677304, 'host_listings_count - guests_included'],
#  [25.659254777391215,
#   'bedrooms - calculated_host_listings_count_private_rooms'],
#  [25.45757071547421, 'host_total_listings_count - bathrooms'],
#  [25.45757071547421, 'host_listings_count - bathrooms'],
#  [25.427318106186657, 'bathrooms - minimum_nights'],
#  [25.155044622598698, 'guests_included - minimum_minimum_nights'],
#  [25.013865779256793, 'host_total_listings_count - bedrooms'],
#  [25.013865779256793, 'host_listings_count - bedrooms'],
#  [24.691171280189582, 'accommodates - beds'],
#  [24.4743609136288,
#   'guests_included - calculated_host_listings_count_private_rooms'],
#  [24.096203297534412, 'guests_included - minimum_nights'],
#  [23.7533403922755, 'host_total_listings_count - beds'],
#  [23.7533403922755, 'host_listings_count - beds'],
#  [23.728129884535875,
#   'host_total_listings_count - calculated_host_listings_count_entire_homes'],
#  [23.728129884535875,
#   'host_listings_count - calculated_host_listings_count_entire_homes'],
#  [23.22896183129128, 'beds - calculated_host_listings_count_private_rooms'],
#  [23.178540815812028, 'availability_30 - availability_60'],
#  [22.96677255079917, 'beds - minimum_nights'],
#  [22.91635153531992, 'beds - minimum_minimum_nights'],
#  [22.886098926032368,
#   'bathrooms - calculated_host_listings_count_private_rooms'],
#  [22.744920082690463,
#   'number_of_reviews - calculated_host_listings_count_shared_rooms'],
#  [21.88272071799526, 'guests_included - maximum_minimum_nights'],
#  [21.529773609640497, 'beds - maximum_minimum_nights'],
#  [21.43397368022992, 'bedrooms - maximum_minimum_nights'],
#  [21.207079110573286, 'bedrooms - minimum_nights_avg_ntm'],
#  [20.1079009731256, 'guests_included - minimum_nights_avg_ntm'],
#  [19.608732919881007, 'accommodates - maximum_minimum_nights'],
#  [18.98855442948621, 'availability_30 - availability_90'],
#  [18.857459789240156, 'host_is_superhost - host_has_profile_pic'],
#  [18.670902031966925, 'beds - minimum_nights_avg_ntm'],
#  [18.665859930419, 'host_is_superhost - requires_license'],
#  [18.665859930419, 'host_is_superhost - has_availability'],
#  [18.41375485302274,
#   'availability_60 - calculated_host_listings_count_shared_rooms'],
#  [18.312912822064238,
#   'availability_30 - calculated_host_listings_count_entire_homes'],
#  [18.166691877174408, 'bathrooms - minimum_nights_avg_ntm'],
#  [18.09106035395553, 'summary - description'],
#  [17.919628901326075,
#   'number_of_reviews_ltm - calculated_host_listings_count_entire_homes'],
#  [17.728029042504918, 'bathrooms - maximum_minimum_nights'],
#  [17.667523823929816, 'accommodates - minimum_nights'],
#  [17.48600816820451, 'availability_60 - availability_365'],
#  [17.405334543437707, 'accommodates - minimum_minimum_nights'],
#  [16.467503655523622,
#   'minimum_minimum_nights - calculated_host_listings_count'],
#  [16.175061765743962, 'accommodates - minimum_nights_avg_ntm'],
#  [16.119598648716785, 'accommodates - calculated_host_listings_count'],
#  [15.857409368224676,
#   'availability_90 - calculated_host_listings_count_shared_rooms'],
#  [15.68597791559522,
#   'number_of_reviews_ltm - calculated_host_listings_count_private_rooms'],
#  [15.660767407855595, 'minimum_nights - calculated_host_listings_count'],
#  [15.277567690213282, 'host_total_listings_count - accommodates'],
#  [15.277567690213282, 'host_listings_count - accommodates'],
#  [15.277567690213282, 'availability_30 - number_of_reviews_ltm'],
#  [15.146473049967227, 'host_total_listings_count - minimum_minimum_nights'],
#  [15.146473049967227, 'host_listings_count - minimum_minimum_nights'],
#  [14.990167901981547,
#   'maximum_minimum_nights - calculated_host_listings_count'],
#  [14.65234709827056, 'host_location - country_code'],
#  [14.51621035647658, 'host_total_listings_count - minimum_nights'],
#  [14.51621035647658, 'host_listings_count - minimum_nights'],
#  [14.395199919326377,
#   'accommodates - calculated_host_listings_count_private_rooms'],
#  [14.18343165431352, 'accommodates - bedrooms'],
#  [14.158221146573894,
#   'minimum_minimum_nights - calculated_host_listings_count_private_rooms'],
#  [14.087631724902941,
#   'availability_60 - calculated_host_listings_count_entire_homes'],
#  [14.072505420259166,
#   'minimum_nights_avg_ntm - calculated_host_listings_count'],
#  [14.047294912519536, 'host_total_listings_count - maximum_minimum_nights'],
#  [14.047294912519536, 'host_listings_count - maximum_minimum_nights'],
#  [13.890989764533856,
#   'number_of_reviews - calculated_host_listings_count_private_rooms'],
#  [13.870821358342155, 'accommodates - bathrooms'],
#  [13.805274038219128, 'availability_30 - availability_365'],
#  [13.482579539151917,
#   'minimum_nights - calculated_host_listings_count_private_rooms'],
#  [13.069127212222053, 'host_total_listings_count - minimum_nights_avg_ntm'],
#  [13.069127212222053, 'host_listings_count - minimum_nights_avg_ntm'],
#  [12.83214843946957,
#   'maximum_minimum_nights - calculated_host_listings_count_private_rooms'],
#  [12.489285534210659,
#   'minimum_nights_avg_ntm - calculated_host_listings_count_private_rooms'],
#  [12.433822417183482,
#   'availability_90 - calculated_host_listings_count_entire_homes'],
#  [12.09095951192457, 'availability_60 - number_of_reviews_ltm'],
#  [12.035496394897393,
#   'number_of_reviews - calculated_host_listings_count_entire_homes'],
#  [11.909443856199264,
#   'availability_365 - calculated_host_listings_count_shared_rooms'],
#  [11.753138708213584,
#   'availability_30 - calculated_host_listings_count_private_rooms'],
#  [10.911107749710078, 'availability_90 - number_of_reviews_ltm'],
#  [10.618665859930418, 'security_deposit - extra_people'],
#  [10.24050824383603,
#   'availability_365 - calculated_host_listings_count_entire_homes'],
#  [10.180003025260929,
#   'bathrooms - calculated_host_listings_count_entire_homes'],
#  [9.45898250390763, 'cleaning_fee - extra_people'],
#  [9.141330106388343, 'availability_30 - number_of_reviews'],
#  [8.843846115060758,
#   'guests_included - calculated_host_listings_count_entire_homes'],
#  [8.400141178843342, 'first_review - last_review'],
#  [8.334593858720314, 'availability_365 - number_of_reviews_ltm'],
#  [8.238793929309736, 'bedrooms - calculated_host_listings_count_entire_homes'],
#  [7.684162759037967, 'bedrooms - number_of_reviews_ltm'],
#  [7.669036454394192, 'bedrooms - number_of_reviews'],
#  [7.643825946654566, 'host_neighbourhood - neighbourhood_cleansed'],
#  [7.467352392477185, 'guests_included - number_of_reviews'],
#  [7.371552463066607, 'guests_included - number_of_reviews_ltm'],
#  [7.255584127464328, 'bathrooms - number_of_reviews_ltm'],
#  [7.210205213533001, 'host_location - street'],
#  [6.993394846972217, 'bathrooms - number_of_reviews'],
#  [6.574900418494428, 'availability_60 - number_of_reviews'],
#  [6.3833005596732715, 'neighbourhood - neighbourhood_cleansed'],
#  [6.348005848837795, 'beds - number_of_reviews'],
#  [6.247163817879292, 'bedrooms - availability_30'],
#  [6.1765743962083395, 'beds - number_of_reviews_ltm'],
#  [6.171532294660414, 'beds - calculated_host_listings_count_entire_homes'],
#  [5.889174607976605,
#   'availability_60 - calculated_host_listings_count_private_rooms'],
#  [5.722785256895073, 'availability_90 - number_of_reviews'],
#  [5.5816064135531684, 'host_total_listings_count - number_of_reviews'],
#  [5.5816064135531684, 'host_listings_count - number_of_reviews'],
#  [5.571522210457318, 'minimum_minimum_nights - availability_30'],
#  [5.505974890334291, 'beds - availability_30'],
#  [5.445469671759189, 'guests_included - availability_30'],
#  [5.430343367115413, 'bathrooms - availability_30'],
#  [5.334543437704835, 'host_total_listings_count - number_of_reviews_ltm'],
#  [5.334543437704835, 'host_listings_count - number_of_reviews_ltm'],
#  [5.294206625321434, 'minimum_nights - availability_30'],
#  [5.284122422225583, 'maximum_minimum_nights - availability_30'],
#  [5.233701406746332, 'state - market'],
#  [5.057227852568951, 'accommodates - number_of_reviews'],
#  [5.042101547925175, 'accommodates - availability_30'],
#  [4.956385821610447, 'city - state'],
#  [4.825291181364393, 'accommodates - number_of_reviews_ltm'],
#  [4.517722986940957, 'number_of_reviews_ltm - reviews_per_month'],
#  [4.517722986940957, 'number_of_reviews - reviews_per_month'],
#  [4.497554580749257, 'number_of_reviews - calculated_host_listings_count'],
#  [4.497554580749257, 'minimum_minimum_nights - number_of_reviews_ltm'],
#  [4.487470377653406,
#   'availability_90 - calculated_host_listings_count_private_rooms'],
#  [4.472344073009631, 'minimum_minimum_nights - number_of_reviews'],
#  [4.396712549790753, 'security_deposit - cleaning_fee'],
#  [4.366459940503202, 'minimum_nights - number_of_reviews'],
#  [4.245449503352997, 'host_neighbourhood - neighbourhood_group_cleansed'],
#  [4.235365300257147, 'number_of_reviews_ltm - calculated_host_listings_count'],
#  [4.215196894065446, 'minimum_nights - number_of_reviews_ltm'],
#  [4.109312761559018, 'availability_30 - calculated_host_listings_count'],
#  [4.099228558463167, 'host_total_listings_count - availability_30'],
#  [4.099228558463167, 'host_listings_count - availability_30'],
#  [4.084102253819392, 'minimum_nights_avg_ntm - availability_30'],
#  [3.9227550042857864, 'availability_365 - number_of_reviews'],
#  [3.8672918872586095, 'maximum_minimum_nights - number_of_reviews'],
#  [3.821912973327283, 'bedrooms - calculated_host_listings_count_shared_rooms'],
#  [3.8017445671355823,
#   'minimum_minimum_nights - calculated_host_listings_count_entire_homes'],
#  [3.6958604346291537,
#   'host_has_profile_pic - require_guest_phone_verification'],
#  [3.680734129985378, 'maximum_minimum_nights - number_of_reviews_ltm'],
#  [3.489134271164221, 'requires_license - require_guest_phone_verification'],
#  [3.489134271164221, 'has_availability - require_guest_phone_verification'],
#  [3.352997529370241, 'minimum_nights_avg_ntm - number_of_reviews'],
#  [3.262239701507588,
#   'minimum_nights - calculated_host_listings_count_entire_homes'],
#  [3.1008924519739827, 'minimum_nights_avg_ntm - number_of_reviews_ltm'],
#  [3.080724045782282,
#   'maximum_minimum_nights - calculated_host_listings_count_entire_homes'],
#  [3.050471436494731,
#   'accommodates - calculated_host_listings_count_entire_homes'],
#  [2.556345484798064,
#   'host_total_listings_count - calculated_host_listings_count_shared_rooms'],
#  [2.556345484798064,
#   'host_listings_count - calculated_host_listings_count_shared_rooms'],
#  [2.5109665708667372, 'street - smart_location'],
#  [2.384914032168608,
#   'minimum_nights_avg_ntm - calculated_host_listings_count_entire_homes'],
#  [2.3748298290727576, 'availability_30 - review_scores_value'],
#  [2.3193667120455808, 'bedrooms - availability_60'],
#  [2.29919830585388, 'availability_30 - review_scores_cleanliness'],
#  [2.238693087278778, 'availability_30 - review_scores_location'],
#  [2.238693087278778, 'availability_30 - review_scores_accuracy'],
#  [2.178187868703676,
#   'availability_365 - calculated_host_listings_count_private_rooms'],
#  [2.1479352594161245, 'availability_30 - review_scores_communication'],
#  [2.1428931578681993, 'availability_30 - review_scores_checkin'],
#  [2.1126405485806483, 'guests_included - reviews_per_month'],
#  [2.072303736197247, 'bathrooms - reviews_per_month'],
#  [2.0672616346493218, 'accommodates - availability_60'],
#  [2.0218827207179952, 'space - description'],
#  [1.9966722129783694, 'beds - availability_60'],
#  [1.9714617052387435, 'bedrooms - reviews_per_month'],
#  [1.865577572732315, 'guests_included - availability_60'],
#  [1.7647355417738115, 'availability_60 - calculated_host_listings_count'],
#  [1.7596934402258864, 'host_total_listings_count - availability_60'],
#  [1.7596934402258864, 'host_listings_count - availability_60'],
#  [1.7546513386779607, 'minimum_nights - availability_60'],
#  [1.7546513386779607, 'availability_60 - review_scores_location'],
#  [1.7546513386779607, 'availability_60 - review_scores_communication'],
#  [1.7445671355821104, 'availability_60 - review_scores_value'],
#  [1.729440830938335, 'beds - reviews_per_month'],
#  [1.7092724247466342, 'maximum_minimum_nights - availability_60'],
#  [1.704230323198709, 'availability_60 - review_scores_checkin'],
#  [1.6790198154590832, 'availability_60 - review_scores_cleanliness'],
#  [1.673977713911158, 'minimum_minimum_nights - availability_60'],
#  [1.6638935108153077, 'availability_60 - review_scores_accuracy'],
#  [1.6285987999798315, 'number_of_reviews_ltm - review_scores_checkin'],
#  [1.6285987999798315, 'bathrooms - availability_60'],
#  [1.6185145968839811, 'number_of_reviews - review_scores_checkin'],
#  [1.5781777845005798, 'number_of_reviews - review_scores_location'],
#  [1.5781777845005798, 'host_has_profile_pic - require_guest_profile_picture'],
#  [1.5731356829526546, 'number_of_reviews - review_scores_value'],
#  [1.552967276760954, 'number_of_reviews_ltm - review_scores_location'],
#  [1.5479251752130287, 'number_of_reviews_ltm - review_scores_value'],
#  [1.5479251752130287, 'number_of_reviews - review_scores_cleanliness'],
#  [1.527756769021328, 'number_of_reviews - review_scores_communication'],
#  [1.527756769021328,
#   'calculated_host_listings_count_entire_homes - calculated_host_listings_count_private_rooms'],
#  [1.5075883628296274, 'number_of_reviews_ltm - review_scores_cleanliness'],
#  [1.5025462612817022, 'number_of_reviews_ltm - review_scores_communication'],
#  [1.4369989411586748, 'minimum_minimum_nights - reviews_per_month'],
#  [1.411788433419049, 'minimum_nights_avg_ntm - availability_60'],
#  [1.3966621287752734, 'number_of_reviews - review_scores_accuracy'],
#  [1.3664095194877224, 'requires_license - require_guest_profile_picture'],
#  [1.3664095194877224, 'has_availability - require_guest_profile_picture'],
#  [1.3512832148439469, 'number_of_reviews_ltm - review_scores_accuracy'],
#  [1.3411990117480965, 'bedrooms - availability_90'],
#  [1.3159885040084707, 'minimum_nights - reviews_per_month'],
#  [1.2201885745978924, 'calculated_host_listings_count - reviews_per_month'],
#  [1.1949780668582666, 'accommodates - review_scores_cleanliness'],
#  [1.1899359653103414, 'price - cleaning_fee'],
#  [1.1899359653103414, 'accommodates - review_scores_value'],
#  [1.1344728482831645, 'host_total_listings_count - availability_90'],
#  [1.1344728482831645, 'host_listings_count - availability_90'],
#  [1.1243886451873142, 'maximum_minimum_nights - reviews_per_month'],
#  [1.1092623405435387, 'accommodates - reviews_per_month'],
#  [1.0991781374476883, 'minimum_nights_avg_ntm - reviews_per_month'],
#  [1.0790097312559876, 'host_total_listings_count - review_scores_value'],
#  [1.0790097312559876, 'host_listings_count - review_scores_value'],
#  [1.0739676297080623, 'accommodates - review_scores_accuracy'],
#  [1.068925528160137, 'review_scores_value - calculated_host_listings_count'],
#  [1.068925528160137, 'minimum_maximum_nights - review_scores_checkin'],
#  [1.063883426612212, 'beds - calculated_host_listings_count_shared_rooms'],
#  [1.0437150204205112, 'maximum_nights_avg_ntm - review_scores_checkin'],
#  [1.038672918872586, 'availability_90 - review_scores_location'],
#  [1.0336308173246609, 'minimum_maximum_nights - review_scores_communication'],
#  [1.0285887157767357, 'maximum_nights - review_scores_checkin'],
#  [1.0285887157767357, 'maximum_maximum_nights - review_scores_checkin'],
#  [1.0285887157767357, 'accommodates - review_scores_checkin'],
#  [1.0235466142288105, 'minimum_maximum_nights - review_scores_location'],
#  [1.0235466142288105, 'bathrooms - availability_90'],
#  [1.0235466142288105, 'availability_90 - calculated_host_listings_count'],
#  [1.0185045126808854, 'maximum_nights_avg_ntm - review_scores_location'],
#  [1.0134624111329602, 'maximum_nights_avg_ntm - review_scores_communication'],
#  [1.008420309585035, 'host_total_listings_count - reviews_per_month'],
#  [1.008420309585035, 'host_total_listings_count - review_scores_cleanliness'],
#  [1.008420309585035, 'host_total_listings_count - review_scores_accuracy'],
#  [1.008420309585035, 'host_listings_count - reviews_per_month'],
#  [1.008420309585035, 'host_listings_count - review_scores_cleanliness'],
#  [1.008420309585035, 'host_listings_count - review_scores_accuracy'],
#  [0.9983361064891847, 'maximum_nights - review_scores_location'],
#  [0.9983361064891847, 'maximum_nights - review_scores_communication'],
#  [0.9983361064891847, 'maximum_maximum_nights - review_scores_location'],
#  [0.9983361064891847, 'maximum_maximum_nights - review_scores_communication'],
#  [0.9983361064891847, 'guests_included - availability_90'],
#  [0.9731255987495588, 'availability_90 - review_scores_checkin'],
#  [0.9680834972016337,
#   'host_total_listings_count - review_scores_communication'],
#  [0.9680834972016337, 'host_listings_count - review_scores_communication'],
#  [0.9630413956537085,
#   'review_scores_accuracy - calculated_host_listings_count'],
#  [0.9630413956537085, 'minimum_maximum_nights - review_scores_accuracy'],
#  [0.9630413956537085, 'beds - availability_90'],
#  [0.9579992941057833, 'accommodates - review_scores_communication'],
#  [0.9529571925578582, 'maximum_nights_avg_ntm - review_scores_accuracy'],
#  [0.9529571925578582, 'accommodates - availability_90'],
#  [0.947915091009933, 'availability_90 - review_scores_communication'],
#  [0.947915091009933, 'availability_90 - review_scores_cleanliness'],
#  [0.9378308879140826, 'accommodates - review_scores_location'],
#  [0.9327887863661575, 'maximum_nights - review_scores_accuracy'],
#  [0.9327887863661575, 'maximum_maximum_nights - review_scores_accuracy'],
#  [0.9327887863661575,
#   'calculated_host_listings_count_private_rooms - reviews_per_month'],
#  [0.917662481722382,
#   'bathrooms - calculated_host_listings_count_shared_rooms'],
#  [0.917662481722382, 'availability_90 - review_scores_accuracy'],
#  [0.9075782786265316, 'minimum_maximum_nights - review_scores_cleanliness'],
#  [0.9025361770786064, 'minimum_nights - availability_90'],
#  [0.8924519739827561, 'maximum_nights_avg_ntm - review_scores_cleanliness'],
#  [0.8874098724348309, 'minimum_minimum_nights - availability_90'],
#  [0.8722835677910552, 'maximum_nights - review_scores_cleanliness'],
#  [0.8722835677910552, 'maximum_maximum_nights - review_scores_cleanliness'],
#  [0.8521151615993545, 'maximum_minimum_nights - availability_90'],
#  [0.8521151615993545, 'availability_90 - review_scores_value'],
#  [0.8470730600514293, 'maximum_minimum_nights - minimum_maximum_nights'],
#  [0.8420309585035042,
#   'review_scores_communication - calculated_host_listings_count'],
#  [0.8420309585035042,
#   'review_scores_checkin - calculated_host_listings_count'],
#  [0.8420309585035042, 'host_total_listings_count - review_scores_checkin'],
#  [0.8420309585035042, 'host_listings_count - review_scores_checkin'],
#  [0.836988856955579, 'minimum_maximum_nights - minimum_nights_avg_ntm'],
#  [0.8319467554076538,
#   'review_scores_cleanliness - calculated_host_listings_count'],
#  [0.806736247668028, 'host_total_listings_count - review_scores_location'],
#  [0.806736247668028, 'host_listings_count - review_scores_location'],
#  [0.7613573337367014,
#   'review_scores_location - calculated_host_listings_count'],
#  [0.7563152321887763, 'price - extra_people'],
#  [0.7411889275450008, 'minimum_minimum_nights - minimum_maximum_nights'],
#  [0.7361468259970756, 'minimum_nights_avg_ntm - availability_90'],
#  [0.7210205213533, 'price - security_deposit'],
#  [0.7008521151615993, 'minimum_nights - minimum_maximum_nights'],
#  [0.6958100136136741, 'bedrooms - availability_365'],
#  [0.6756416074219734, 'minimum_maximum_nights - review_scores_value'],
#  [0.6605153027781979, 'maximum_nights_avg_ntm - review_scores_value'],
#  [0.6453889981344224, 'maximum_nights - review_scores_value'],
#  [0.6453889981344224, 'maximum_maximum_nights - review_scores_value'],
#  [0.6403468965864972, 'host_location - country'],
#  [0.5899258811072455, 'last_scraped - last_review'],
#  [0.5899258811072455,
#   'guests_included - calculated_host_listings_count_shared_rooms'],
#  [0.5899258811072455, 'calendar_last_scraped - last_review'],
#  [0.5848837795593204,
#   'review_scores_value - calculated_host_listings_count_entire_homes'],
#  [0.57479957646347,
#   'review_scores_accuracy - calculated_host_listings_count_entire_homes'],
#  [0.5697574749155448,
#   'review_scores_location - calculated_host_listings_count_entire_homes'],
#  [0.5697574749155448, 'maximum_nights - maximum_minimum_nights'],
#  [0.5647153733676197, 'maximum_minimum_nights - maximum_nights_avg_ntm'],
#  [0.5647153733676197, 'maximum_minimum_nights - maximum_maximum_nights'],
#  [0.544546967175919,
#   'review_scores_checkin - calculated_host_listings_count_entire_homes'],
#  [0.5395048656279938,
#   'calculated_host_listings_count - calculated_host_listings_count_shared_rooms'],
#  [0.5294206625321434, 'minimum_nights - maximum_nights'],
#  [0.5243785609842182,
#   'review_scores_communication - calculated_host_listings_count_entire_homes'],
#  [0.519336459436293, 'minimum_nights - maximum_nights_avg_ntm'],
#  [0.519336459436293, 'minimum_nights - maximum_maximum_nights'],
#  [0.5092522563404427, 'maximum_nights - minimum_nights_avg_ntm'],
#  [0.5092522563404427, 'maximum_nights - minimum_minimum_nights'],
#  [0.5092522563404427,
#   'calculated_host_listings_count_entire_homes - reviews_per_month'],
#  [0.49916805324459235, 'minimum_nights_avg_ntm - maximum_nights_avg_ntm'],
#  [0.49916805324459235, 'minimum_minimum_nights - maximum_nights_avg_ntm'],
#  [0.49916805324459235, 'minimum_minimum_nights - maximum_maximum_nights'],
#  [0.49916805324459235, 'maximum_maximum_nights - minimum_nights_avg_ntm'],
#  [0.489083850148742, 'beds - review_scores_value'],
#  [0.4739575455049665,
#   'review_scores_cleanliness - calculated_host_listings_count_entire_homes'],
#  [0.458831240861191, 'bathrooms - availability_365'],
#  [0.4537891393132658, 'maximum_nights - availability_60'],
#  [0.44370493621741547, 'minimum_maximum_nights - availability_60'],
#  [0.44370493621741547, 'maximum_maximum_nights - availability_60'],
#  [0.4386628346694902, 'maximum_nights_avg_ntm - availability_60'],
#  [0.42857863157363985, 'host_total_listings_count - availability_365'],
#  [0.42857863157363985, 'host_listings_count - availability_365'],
#  [0.42857863157363985, 'beds - review_scores_accuracy'],
#  [0.4184944284777895, 'guests_included - review_scores_value'],
#  [0.4184944284777895, 'beds - availability_365'],
#  [0.41345232692986433, 'minimum_maximum_nights - availability_30'],
#  [0.41345232692986433, 'maximum_nights - availability_90'],
#  [0.41345232692986433, 'beds - review_scores_cleanliness'],
#  [0.41345232692986433, 'accommodates - availability_365'],
#  [0.40841022538193916, 'minimum_maximum_nights - availability_90'],
#  [0.40841022538193916, 'maximum_maximum_nights - availability_90'],
#  [0.403368123834014, 'maximum_nights_avg_ntm - availability_90'],
#  [0.403368123834014, 'guests_included - availability_365'],
#  [0.3983260222860888, 'minimum_maximum_nights - number_of_reviews_ltm'],
#  [0.39328392073816365, 'maximum_nights - availability_30'],
#  [0.3882418191902385, 'maximum_maximum_nights - availability_30'],
#  [0.3831997176423133, 'maximum_nights_avg_ntm - availability_30'],
#  [0.3831997176423133, 'beds - review_scores_communication'],
#  [0.37311551454646297, 'guests_included - review_scores_accuracy'],
#  [0.3680734129985378, 'neighbourhood_cleansed - neighbourhood_group_cleansed'],
#  [0.36303131145061257, 'beds - review_scores_checkin'],
#  [0.36303131145061257, 'availability_365 - calculated_host_listings_count'],
#  [0.3579892099026874, 'maximum_nights - number_of_reviews_ltm'],
#  [0.3579892099026874, 'guests_included - review_scores_checkin'],
#  [0.3579892099026874, 'bedrooms - minimum_maximum_nights'],
#  [0.35294710835476223, 'maximum_nights_avg_ntm - number_of_reviews_ltm'],
#  [0.35294710835476223, 'maximum_maximum_nights - number_of_reviews_ltm'],
#  [0.35294710835476223, 'guests_included - review_scores_cleanliness'],
#  [0.3428629052589119, 'minimum_nights - availability_365'],
#  [0.3428629052589119, 'minimum_maximum_nights - number_of_reviews'],
#  [0.3428629052589119, 'guests_included - review_scores_communication'],
#  [0.3378208037109867,
#   'minimum_nights - calculated_host_listings_count_shared_rooms'],
#  [0.33277870216306155, 'notes - license'],
#  [0.33277870216306155,
#   'minimum_minimum_nights - calculated_host_listings_count_shared_rooms'],
#  [0.3277366006151364, 'maximum_minimum_nights - availability_365'],
#  [0.3226944990672112, 'minimum_minimum_nights - availability_365'],
#  [0.31765239751928603, 'guests_included - review_scores_location'],
#  [0.31261029597136086,
#   'review_scores_accuracy - calculated_host_listings_count_private_rooms'],
#  [0.3075681944234357,
#   'maximum_minimum_nights - calculated_host_listings_count_shared_rooms'],
#  [0.3025260928755105, 'maximum_minimum_nights - review_scores_value'],
#  [0.29748399132758535,
#   'review_scores_value - calculated_host_listings_count_private_rooms'],
#  [0.29748399132758535, 'minimum_nights_avg_ntm - availability_365'],
#  [0.29748399132758535, 'beds - review_scores_location'],
#  [0.2924418897796602, 'availability_30 - reviews_per_month'],
#  [0.287399788231735,
#   'minimum_nights_avg_ntm - calculated_host_listings_count_shared_rooms'],
#  [0.287399788231735, 'maximum_maximum_nights - availability_365'],
#  [0.28235768668380984, 'maximum_minimum_nights - review_scores_accuracy'],
#  [0.28235768668380984, 'maximum_maximum_nights - number_of_reviews'],
#  [0.28235768668380984, 'guests_included - minimum_maximum_nights'],
#  [0.28235768668380984, 'accommodates - minimum_maximum_nights'],
#  [0.27731558513588467,
#   'review_scores_cleanliness - calculated_host_listings_count_private_rooms'],
#  [0.27731558513588467, 'minimum_maximum_nights - availability_365'],
#  [0.27731558513588467, 'maximum_nights_avg_ntm - number_of_reviews'],
#  [0.27731558513588467, 'maximum_nights_avg_ntm - availability_365'],
#  [0.27731558513588467, 'maximum_nights - number_of_reviews'],
#  [0.27731558513588467, 'maximum_nights - availability_365'],
#  [0.27731558513588467, 'availability_90 - review_scores_rating'],
#  [0.2722734835879595,
#   'accommodates - calculated_host_listings_count_shared_rooms'],
#  [0.2621892804921091, 'maximum_minimum_nights - review_scores_communication'],
#  [0.25714717894418393, 'space - access'],
#  [0.25714717894418393,
#   'review_scores_checkin - calculated_host_listings_count_private_rooms'],
#  [0.25714717894418393, 'maximum_minimum_nights - review_scores_cleanliness'],
#  [0.25210507739625876, 'summary - space'],
#  [0.25210507739625876, 'maximum_minimum_nights - review_scores_checkin'],
#  [0.24202087430040842,
#   'review_scores_communication - calculated_host_listings_count_private_rooms'],
#  [0.24202087430040842, 'notes - interaction'],
#  [0.24202087430040842, 'host_name - market'],
#  [0.23193667120455808, 'availability_365 - review_scores_cleanliness'],
#  [0.2268945696566329, 'host_name - city'],
#  [0.22185246810870773, 'beds - minimum_maximum_nights'],
#  [0.2168103665607825, 'host_total_listings_count - minimum_maximum_nights'],
#  [0.2168103665607825, 'host_listings_count - minimum_maximum_nights'],
#  [0.2168103665607825, 'availability_365 - review_scores_location'],
#  [0.2168103665607825, 'availability_365 - review_scores_checkin'],
#  [0.21176826501285734, 'host_has_profile_pic - is_business_travel_ready'],
#  [0.21176826501285734, 'availability_365 - review_scores_communication'],
#  [0.20672616346493217,
#   'minimum_maximum_nights - calculated_host_listings_count'],
#  [0.20672616346493217, 'availability_365 - review_scores_accuracy'],
#  [0.19159985882115665,
#   'review_scores_location - calculated_host_listings_count_private_rooms'],
#  [0.19159985882115665, 'notes - house_rules'],
#  [0.19159985882115665, 'notes - access'],
#  [0.18151565572530629, 'space - neighborhood_overview'],
#  [0.18151565572530629,
#   'minimum_maximum_nights - calculated_host_listings_count_private_rooms'],
#  [0.18151565572530629, 'availability_365 - review_scores_value'],
#  [0.18151565572530629, 'availability_365 - review_scores_rating'],
#  [0.18151565572530629, 'accommodates - maximum_nights'],
#  [0.17647355417738111, 'minimum_nights - review_scores_cleanliness'],
#  [0.17647355417738111, 'maximum_minimum_nights - review_scores_location'],
#  [0.17647355417738111, 'accommodates - maximum_nights_avg_ntm'],
#  [0.17647355417738111, 'accommodates - maximum_maximum_nights'],
#  [0.17143145262945594, 'minimum_nights - review_scores_accuracy'],
#  [0.16638935108153077, 'bedrooms - review_scores_value'],
#  [0.16638935108153077, 'bathrooms - minimum_maximum_nights'],
#  [0.15630514798568043, 'number_of_reviews - review_scores_rating'],
#  [0.15630514798568043, 'minimum_minimum_nights - review_scores_cleanliness'],
#  [0.15630514798568043, 'maximum_nights - review_scores_rating'],
#  [0.15630514798568043, 'maximum_maximum_nights - review_scores_rating'],
#  [0.15126304643775526, 'minimum_nights - review_scores_value'],
#  [0.15126304643775526, 'minimum_nights - review_scores_communication'],
#  [0.15126304643775526, 'minimum_maximum_nights - review_scores_rating'],
#  [0.15126304643775526, 'maximum_nights_avg_ntm - review_scores_rating'],
#  [0.1462209448898301, 'minimum_minimum_nights - review_scores_accuracy'],
#  [0.14117884334190492, 'minimum_nights - review_scores_checkin'],
#  [0.14117884334190492, 'minimum_minimum_nights - review_scores_communication'],
#  [0.14117884334190492, 'host_total_listings_count - maximum_nights_avg_ntm'],
#  [0.14117884334190492, 'host_total_listings_count - maximum_nights'],
#  [0.14117884334190492, 'host_total_listings_count - maximum_maximum_nights'],
#  [0.14117884334190492, 'host_listings_count - maximum_nights_avg_ntm'],
#  [0.14117884334190492, 'host_listings_count - maximum_nights'],
#  [0.14117884334190492, 'host_listings_count - maximum_maximum_nights'],
#  [0.13613674179397975, 'neighborhood_overview - notes'],
#  [0.13613674179397975, 'minimum_nights_avg_ntm - review_scores_communication'],
#  [0.13613674179397975, 'minimum_nights_avg_ntm - review_scores_cleanliness'],
#  [0.13613674179397975, 'minimum_minimum_nights - review_scores_checkin'],
#  [0.13613674179397975,
#   'maximum_nights_avg_ntm - calculated_host_listings_count'],
#  [0.13613674179397975, 'maximum_nights - calculated_host_listings_count'],
#  [0.13613674179397975,
#   'maximum_maximum_nights - calculated_host_listings_count'],
#  [0.13613674179397975, 'bedrooms - review_scores_accuracy'],
#  [0.12605253869812938, 'neighborhood_overview - transit'],
#  [0.12605253869812938, 'minimum_nights_avg_ntm - review_scores_accuracy'],
#  [0.12101043715020421, 'minimum_nights_avg_ntm - review_scores_checkin'],
#  [0.12101043715020421, 'minimum_minimum_nights - review_scores_value'],
#  [0.11596833560227904, 'minimum_nights_avg_ntm - review_scores_value'],
#  [0.11596833560227904, 'bedrooms - review_scores_cleanliness'],
#  [0.10588413250642867, 'description - notes'],
#  [0.10588413250642867, 'bedrooms - review_scores_communication'],
#  [0.10588413250642867, 'bedrooms - review_scores_checkin'],
#  [0.1008420309585035, 'minimum_minimum_nights - review_scores_location'],
#  [0.1008420309585035,
#   'minimum_maximum_nights - calculated_host_listings_count_entire_homes'],
#  [0.1008420309585035, 'access - interaction'],
#  [0.09579992941057833, 'name - summary'],
#  [0.09579992941057833, 'bathrooms - review_scores_value'],
#  [0.09075782786265314, 'minimum_nights - review_scores_location'],
#  [0.09075782786265314,
#   'maximum_nights - calculated_host_listings_count_private_rooms'],
#  [0.09075782786265314, 'bedrooms - maximum_nights'],
#  [0.08571572631472797, 'space - notes'],
#  [0.08571572631472797,
#   'review_scores_rating - calculated_host_listings_count_entire_homes'],
#  [0.08571572631472797, 'neighborhood_overview - access'],
#  [0.08571572631472797,
#   'maximum_nights_avg_ntm - calculated_host_listings_count_private_rooms'],
#  [0.08571572631472797,
#   'maximum_maximum_nights - calculated_host_listings_count_private_rooms'],
#  [0.08571572631472797, 'description - neighborhood_overview'],
#  [0.08571572631472797, 'beds - maximum_nights'],
#  [0.0806736247668028, 'review_scores_rating - calculated_host_listings_count'],
#  [0.0806736247668028, 'neighbourhood_group_cleansed - city'],
#  [0.0806736247668028, 'guests_included - maximum_nights'],
#  [0.0806736247668028, 'beds - maximum_nights_avg_ntm'],
#  [0.0806736247668028, 'beds - maximum_maximum_nights'],
#  [0.0806736247668028, 'bedrooms - maximum_nights_avg_ntm'],
#  [0.0806736247668028, 'bedrooms - maximum_maximum_nights'],
#  [0.07563152321887763, 'neighbourhood - city'],
#  [0.07563152321887763, 'bedrooms - review_scores_location'],
#  [0.07563152321887763, 'bathrooms - maximum_nights_avg_ntm'],
#  [0.07563152321887763, 'bathrooms - maximum_nights'],
#  [0.07563152321887763, 'bathrooms - maximum_maximum_nights'],
#  [0.07058942167095246, 'state - country'],
#  [0.07058942167095246, 'guests_included - maximum_nights_avg_ntm'],
#  [0.07058942167095246, 'guests_included - maximum_maximum_nights'],
#  [0.07058942167095246, 'description - access'],
#  [0.07058942167095246, 'bathrooms - review_scores_communication'],
#  [0.07058942167095246, 'bathrooms - review_scores_cleanliness'],
#  [0.06554732012302728, 'minimum_nights_avg_ntm - review_scores_location'],
#  [0.06554732012302728, 'bathrooms - review_scores_accuracy'],
#  [0.06554732012302728, 'availability_60 - reviews_per_month'],
#  [0.060505218575102104, 'summary - neighborhood_overview'],
#  [0.060505218575102104,
#   'minimum_maximum_nights - calculated_host_listings_count_shared_rooms'],
#  [0.060505218575102104,
#   'maximum_nights - calculated_host_listings_count_shared_rooms'],
#  [0.060505218575102104, 'last_scraped - first_review'],
#  [0.060505218575102104, 'calendar_last_scraped - first_review'],
#  [0.05042101547925175, 'weekly_price - security_deposit'],
#  [0.05042101547925175, 'transit - access'],
#  [0.05042101547925175,
#   'maximum_nights_avg_ntm - calculated_host_listings_count_entire_homes'],
#  [0.05042101547925175,
#   'maximum_nights - calculated_host_listings_count_entire_homes'],
#  [0.05042101547925175,
#   'maximum_maximum_nights - calculated_host_listings_count_entire_homes'],
#  [0.05042101547925175, 'availability_60 - review_scores_rating'],
#  [0.04537891393132657, 'transit - interaction'],
#  [0.04537891393132657, 'summary - access'],
#  [0.04537891393132657, 'notes - transit'],
#  [0.04537891393132657, 'host_since - first_review'],
#  [0.0403368123834014, 'minimum_maximum_nights - reviews_per_month'],
#  [0.03529471083547623, 'summary - notes'],
#  [0.03529471083547623, 'neighborhood_overview - neighbourhood_group_cleansed'],
#  [0.03529471083547623, 'maximum_nights_avg_ntm - reviews_per_month'],
#  [0.03529471083547623, 'maximum_nights - reviews_per_month'],
#  [0.03529471083547623, 'maximum_maximum_nights - reviews_per_month'],
#  [0.03529471083547623, 'host_about - market'],
#  [0.03529471083547623, 'host_about - city'],
#  [0.03529471083547623,
#   'calculated_host_listings_count_shared_rooms - reviews_per_month'],
#  [0.03529471083547623, 'bathrooms - review_scores_checkin'],
#  [0.03529471083547623, 'availability_90 - reviews_per_month'],
#  [0.030252609287551052, 'summary - license'],
#  [0.030252609287551052, 'space - transit'],
#  [0.030252609287551052, 'neighborhood_overview - neighbourhood'],
#  [0.030252609287551052, 'name - host_name'],
#  [0.030252609287551052, 'monthly_price - security_deposit'],
#  [0.030252609287551052, 'interaction - house_rules'],
#  [0.030252609287551052, 'availability_365 - reviews_per_month'],
#  [0.025210507739625874, 'name - description'],
#  [0.025210507739625874, 'description - transit'],
#  [0.025210507739625874, 'access - host_about'],
#  [0.0201684061917007, 'space - interaction'],
#  [0.0201684061917007, 'review_scores_value - reviews_per_month'],
#  [0.0201684061917007, 'review_scores_location - reviews_per_month'],
#  [0.0201684061917007, 'review_scores_communication - reviews_per_month'],
#  [0.0201684061917007,
#   'review_scores_communication - calculated_host_listings_count_shared_rooms'],
#  [0.0201684061917007,
#   'review_scores_cleanliness - calculated_host_listings_count_shared_rooms'],
#  [0.0201684061917007,
#   'review_scores_checkin - calculated_host_listings_count_shared_rooms'],
#  [0.0201684061917007, 'maximum_minimum_nights - review_scores_rating'],
#  [0.0201684061917007, 'host_since - last_review'],
#  [0.0201684061917007, 'description - interaction'],
#  [0.0201684061917007, 'bathrooms - review_scores_location'],
#  [0.015126304643775526, 'summary - interaction'],
#  [0.015126304643775526, 'space - house_rules'],
#  [0.015126304643775526,
#   'review_scores_value - calculated_host_listings_count_shared_rooms'],
#  [0.015126304643775526,
#   'review_scores_location - calculated_host_listings_count_shared_rooms'],
#  [0.015126304643775526, 'review_scores_cleanliness - reviews_per_month'],
#  [0.015126304643775526,
#   'review_scores_accuracy - calculated_host_listings_count_shared_rooms'],
#  [0.015126304643775526, 'neighborhood_overview - interaction'],
#  [0.015126304643775526, 'host_name - state'],
#  [0.015126304643775526, 'host_name - host_about'],
#  [0.015126304643775526, 'access - house_rules'],
#  [0.01008420309585035, 'summary - transit'],
#  [0.01008420309585035, 'review_scores_checkin - reviews_per_month'],
#  [0.01008420309585035, 'review_scores_accuracy - reviews_per_month'],
#  [0.01008420309585035, 'number_of_reviews_ltm - review_scores_rating'],
#  [0.01008420309585035, 'notes - market'],
#  [0.01008420309585035, 'notes - city'],
#  [0.01008420309585035, 'neighborhood_overview - neighbourhood_cleansed'],
#  [0.01008420309585035, 'name - space'],
#  [0.01008420309585035, 'minimum_nights_avg_ntm - review_scores_rating'],
#  [0.01008420309585035, 'minimum_nights - review_scores_rating'],
#  [0.01008420309585035, 'minimum_minimum_nights - review_scores_rating'],
#  [0.01008420309585035, 'host_location - market'],
#  [0.01008420309585035, 'host_location - city'],
#  [0.005042101547925175, 'zipcode - number_of_reviews_ltm'],
#  [0.005042101547925175, 'zipcode - number_of_reviews'],
#  [0.005042101547925175,
#   'zipcode - calculated_host_listings_count_shared_rooms'],
#  [0.005042101547925175,
#   'zipcode - calculated_host_listings_count_private_rooms'],
#  [0.005042101547925175, 'zipcode - bedrooms'],
#  [0.005042101547925175, 'weekly_price - monthly_price'],
#  [0.005042101547925175, 'transit - house_rules'],
#  [0.005042101547925175, 'transit - host_about'],
#  [0.005042101547925175, 'summary - house_rules'],
#  [0.005042101547925175, 'neighborhood_overview - house_rules'],
#  [0.005042101547925175, 'neighborhood_overview - host_neighbourhood'],
#  [0.005042101547925175, 'name - transit'],
#  [0.005042101547925175, 'name - notes'],
#  [0.005042101547925175, 'name - neighbourhood_group_cleansed'],
#  [0.005042101547925175, 'name - neighbourhood'],
#  [0.005042101547925175, 'name - neighborhood_overview'],
#  [0.005042101547925175, 'name - interaction'],
#  [0.005042101547925175, 'name - host_about'],
#  [0.005042101547925175, 'name - access'],
#  [0.005042101547925175,
#   'maximum_nights_avg_ntm - calculated_host_listings_count_shared_rooms'],
#  [0.005042101547925175,
#   'maximum_maximum_nights - calculated_host_listings_count_shared_rooms'],
#  [0.005042101547925175, 'interaction - require_guest_profile_picture'],
#  [0.005042101547925175, 'interaction - require_guest_phone_verification'],
#  [0.005042101547925175, 'interaction - is_location_exact'],
#  [0.005042101547925175, 'interaction - is_business_travel_ready'],
#  [0.005042101547925175, 'interaction - host_identity_verified'],
#  [0.005042101547925175, 'interaction - host_about'],
#  [0.005042101547925175, 'house_rules - host_about'],
#  [0.005042101547925175, 'host_name - property_type'],
#  [0.005042101547925175, 'host_name - neighbourhood'],
#  [0.005042101547925175, 'host_name - host_neighbourhood'],
#  [0.005042101547925175, 'host_about - country'],
#  [0.005042101547925175, 'city - zipcode'],
#  [0.005042101547925175, 'availability_30 - review_scores_rating'],
#  [0.0, 'zipcode - weekly_price'],
#  [0.0, 'zipcode - smart_location'],
#  [0.0, 'zipcode - security_deposit'],
#  [0.0, 'zipcode - room_type'],
#  [0.0, 'zipcode - reviews_per_month'],
#  [0.0, 'zipcode - review_scores_value'],
#  [0.0, 'zipcode - review_scores_rating'],
#  [0.0, 'zipcode - review_scores_location'],
#  [0.0, 'zipcode - review_scores_communication'],
#  [0.0, 'zipcode - review_scores_cleanliness'],
#  [0.0, 'zipcode - review_scores_checkin'],
#  [0.0, 'zipcode - review_scores_accuracy'],
#  [0.0, 'zipcode - requires_license'],
#  [0.0, 'zipcode - require_guest_profile_picture'],
#  [0.0, 'zipcode - require_guest_phone_verification'],
#  [0.0, 'zipcode - property_type'],
#  [0.0, 'zipcode - price'],
#  [0.0, 'zipcode - monthly_price'],
#  [0.0, 'zipcode - minimum_nights_avg_ntm'],
#  [0.0, 'zipcode - minimum_nights'],
#  [0.0, 'zipcode - minimum_minimum_nights'],
#  [0.0, 'zipcode - minimum_maximum_nights'],
#  [0.0, 'zipcode - maximum_nights_avg_ntm'],
#  [0.0, 'zipcode - maximum_nights'],
#  [0.0, 'zipcode - maximum_minimum_nights'],
#  [0.0, 'zipcode - maximum_maximum_nights'],
#  [0.0, 'zipcode - market'],
#  [0.0, 'zipcode - longitude'],
#  [0.0, 'zipcode - license'],
#  [0.0, 'zipcode - latitude'],
#  [0.0, 'zipcode - last_review'],
#  [0.0, 'zipcode - is_location_exact'],
#  [0.0, 'zipcode - is_business_travel_ready'],
#  [0.0, 'zipcode - instant_bookable'],
#  [0.0, 'zipcode - has_availability'],
#  [0.0, 'zipcode - guests_included'],
#  [0.0, 'zipcode - first_review'],
#  [0.0, 'zipcode - extra_people'],
#  [0.0, 'zipcode - country_code'],
#  [0.0, 'zipcode - country'],
#  [0.0, 'zipcode - cleaning_fee'],
#  [0.0, 'zipcode - cancellation_policy'],
#  [0.0, 'zipcode - calendar_updated'],
#  [0.0, 'zipcode - calendar_last_scraped'],
#  [0.0, 'zipcode - calculated_host_listings_count_entire_homes'],
#  [0.0, 'zipcode - calculated_host_listings_count'],
#  [0.0, 'zipcode - beds'],
#  [0.0, 'zipcode - bed_type'],
#  [0.0, 'zipcode - bathrooms'],
#  [0.0, 'zipcode - availability_90'],
#  [0.0, 'zipcode - availability_60'],
#  [0.0, 'zipcode - availability_365'],
#  [0.0, 'zipcode - availability_30'],
#  [0.0, 'zipcode - amenities'],
#  [0.0, 'zipcode - accommodates'],
#  [0.0, 'weekly_price - reviews_per_month'],
#  [0.0, 'weekly_price - review_scores_value'],
#  [0.0, 'weekly_price - review_scores_rating'],
#  [0.0, 'weekly_price - review_scores_location'],
#  [0.0, 'weekly_price - review_scores_communication'],
#  [0.0, 'weekly_price - review_scores_cleanliness'],
#  [0.0, 'weekly_price - review_scores_checkin'],
#  [0.0, 'weekly_price - review_scores_accuracy'],
#  [0.0, 'weekly_price - requires_license'],
#  [0.0, 'weekly_price - require_guest_profile_picture'],
#  [0.0, 'weekly_price - require_guest_phone_verification'],
#  [0.0, 'weekly_price - number_of_reviews_ltm'],
#  [0.0, 'weekly_price - number_of_reviews'],
#  [0.0, 'weekly_price - minimum_nights_avg_ntm'],
#  [0.0, 'weekly_price - minimum_nights'],
#  [0.0, 'weekly_price - minimum_minimum_nights'],
#  [0.0, 'weekly_price - minimum_maximum_nights'],
#  [0.0, 'weekly_price - maximum_nights_avg_ntm'],
#  [0.0, 'weekly_price - maximum_nights'],
#  [0.0, 'weekly_price - maximum_minimum_nights'],
#  [0.0, 'weekly_price - maximum_maximum_nights'],
#  [0.0, 'weekly_price - license'],
#  [0.0, 'weekly_price - last_review'],
#  [0.0, 'weekly_price - is_business_travel_ready'],
#  [0.0, 'weekly_price - instant_bookable'],
#  [0.0, 'weekly_price - has_availability'],
#  [0.0, 'weekly_price - guests_included'],
#  [0.0, 'weekly_price - first_review'],
#  [0.0, 'weekly_price - extra_people'],
#  [0.0, 'weekly_price - cleaning_fee'],
#  [0.0, 'weekly_price - cancellation_policy'],
#  [0.0, 'weekly_price - calendar_updated'],
#  [0.0, 'weekly_price - calendar_last_scraped'],
#  [0.0, 'weekly_price - calculated_host_listings_count_shared_rooms'],
#  [0.0, 'weekly_price - calculated_host_listings_count_private_rooms'],
#  [0.0, 'weekly_price - calculated_host_listings_count_entire_homes'],
#  [0.0, 'weekly_price - calculated_host_listings_count'],
#  [0.0, 'weekly_price - availability_90'],
#  [0.0, 'weekly_price - availability_60'],
#  [0.0, 'weekly_price - availability_365'],
#  [0.0, 'weekly_price - availability_30'],
#  [0.0, 'transit - zipcode'],
#  [0.0, 'transit - weekly_price'],
#  [0.0, 'transit - street'],
#  [0.0, 'transit - state'],
#  [0.0, 'transit - smart_location'],
#  [0.0, 'transit - security_deposit'],
#  [0.0, 'transit - room_type'],
#  [0.0, 'transit - reviews_per_month'],
#  [0.0, 'transit - review_scores_value'],
#  [0.0, 'transit - review_scores_rating'],
#  [0.0, 'transit - review_scores_location'],
#  [0.0, 'transit - review_scores_communication'],
#  [0.0, 'transit - review_scores_cleanliness'],
#  [0.0, 'transit - review_scores_checkin'],
#  [0.0, 'transit - review_scores_accuracy'],
#  [0.0, 'transit - requires_license'],
#  [0.0, 'transit - require_guest_profile_picture'],
#  [0.0, 'transit - require_guest_phone_verification'],
#  [0.0, 'transit - property_type'],
#  [0.0, 'transit - price'],
#  [0.0, 'transit - picture_url'],
#  [0.0, 'transit - number_of_reviews_ltm'],
#  [0.0, 'transit - number_of_reviews'],
#  [0.0, 'transit - neighbourhood_group_cleansed'],
#  [0.0, 'transit - neighbourhood_cleansed'],
#  [0.0, 'transit - neighbourhood'],
#  [0.0, 'transit - monthly_price'],
#  [0.0, 'transit - minimum_nights_avg_ntm'],
#  [0.0, 'transit - minimum_nights'],
#  [0.0, 'transit - minimum_minimum_nights'],
#  [0.0, 'transit - minimum_maximum_nights'],
#  [0.0, 'transit - maximum_nights_avg_ntm'],
#  [0.0, 'transit - maximum_nights'],
#  [0.0, 'transit - maximum_minimum_nights'],
#  [0.0, 'transit - maximum_maximum_nights'],
#  [0.0, 'transit - market'],
#  [0.0, 'transit - longitude'],
#  [0.0, 'transit - license'],
#  [0.0, 'transit - latitude'],
#  [0.0, 'transit - last_review'],
#  [0.0, 'transit - is_location_exact'],
#  [0.0, 'transit - is_business_travel_ready'],
#  [0.0, 'transit - instant_bookable'],
#  [0.0, 'transit - host_verifications'],
#  [0.0, 'transit - host_url'],
#  [0.0, 'transit - host_total_listings_count'],
#  [0.0, 'transit - host_thumbnail_url'],
#  [0.0, 'transit - host_since'],
#  [0.0, 'transit - host_response_time'],
#  [0.0, 'transit - host_response_rate'],
#  [0.0, 'transit - host_picture_url'],
#  [0.0, 'transit - host_neighbourhood'],
#  [0.0, 'transit - host_name'],
#  [0.0, 'transit - host_location'],
#  [0.0, 'transit - host_listings_count'],
#  [0.0, 'transit - host_is_superhost'],
#  [0.0, 'transit - host_identity_verified'],
#  [0.0, 'transit - host_id'],
#  [0.0, 'transit - host_has_profile_pic'],
#  [0.0, 'transit - has_availability'],
#  [0.0, 'transit - guests_included'],
#  [0.0, 'transit - first_review'],
#  [0.0, 'transit - extra_people'],
#  [0.0, 'transit - country_code'],
#  [0.0, 'transit - country'],
#  [0.0, 'transit - cleaning_fee'],
#  [0.0, 'transit - city'],
#  [0.0, 'transit - cancellation_policy'],
#  [0.0, 'transit - calendar_updated'],
#  [0.0, 'transit - calendar_last_scraped'],
#  [0.0, 'transit - calculated_host_listings_count_shared_rooms'],
#  [0.0, 'transit - calculated_host_listings_count_private_rooms'],
#  [0.0, 'transit - calculated_host_listings_count_entire_homes'],
#  [0.0, 'transit - calculated_host_listings_count'],
#  [0.0, 'transit - beds'],
#  [0.0, 'transit - bedrooms'],
#  [0.0, 'transit - bed_type'],
#  [0.0, 'transit - bathrooms'],
#  [0.0, 'transit - availability_90'],
#  [0.0, 'transit - availability_60'],
#  [0.0, 'transit - availability_365'],
#  [0.0, 'transit - availability_30'],
#  [0.0, 'transit - amenities'],
#  [0.0, 'transit - accommodates'],
#  [0.0, 'summary - zipcode'],
#  [0.0, 'summary - weekly_price'],
#  [0.0, 'summary - street'],
#  [0.0, 'summary - state'],
#  [0.0, 'summary - smart_location'],
#  [0.0, 'summary - security_deposit'],
#  [0.0, 'summary - room_type'],
#  [0.0, 'summary - reviews_per_month'],
#  [0.0, 'summary - review_scores_value'],
#  [0.0, 'summary - review_scores_rating'],
#  [0.0, 'summary - review_scores_location'],
#  [0.0, 'summary - review_scores_communication'],
#  [0.0, 'summary - review_scores_cleanliness'],
#  [0.0, 'summary - review_scores_checkin'],
#  [0.0, 'summary - review_scores_accuracy'],
#  [0.0, 'summary - requires_license'],
#  [0.0, 'summary - require_guest_profile_picture'],
#  [0.0, 'summary - require_guest_phone_verification'],
#  [0.0, 'summary - property_type'],
#  [0.0, 'summary - price'],
#  [0.0, 'summary - picture_url'],
#  [0.0, 'summary - number_of_reviews_ltm'],
#  [0.0, 'summary - number_of_reviews'],
#  [0.0, 'summary - neighbourhood_group_cleansed'],
#  [0.0, 'summary - neighbourhood_cleansed'],
#  [0.0, 'summary - neighbourhood'],
#  [0.0, 'summary - monthly_price'],
#  [0.0, 'summary - minimum_nights_avg_ntm'],
#  [0.0, 'summary - minimum_nights'],
#  [0.0, 'summary - minimum_minimum_nights'],
#  [0.0, 'summary - minimum_maximum_nights'],
#  [0.0, 'summary - maximum_nights_avg_ntm'],
#  [0.0, 'summary - maximum_nights'],
#  [0.0, 'summary - maximum_minimum_nights'],
#  [0.0, 'summary - maximum_maximum_nights'],
#  [0.0, 'summary - market'],
#  [0.0, 'summary - longitude'],
#  [0.0, 'summary - latitude'],
#  [0.0, 'summary - last_review'],
#  [0.0, 'summary - is_location_exact'],
#  [0.0, 'summary - is_business_travel_ready'],
#  [0.0, 'summary - instant_bookable'],
#  [0.0, 'summary - host_verifications'],
#  [0.0, 'summary - host_url'],
#  [0.0, 'summary - host_total_listings_count'],
#  [0.0, 'summary - host_thumbnail_url'],
#  [0.0, 'summary - host_since'],
#  [0.0, 'summary - host_response_time'],
#  [0.0, 'summary - host_response_rate'],
#  [0.0, 'summary - host_picture_url'],
#  [0.0, 'summary - host_neighbourhood'],
#  [0.0, 'summary - host_name'],
#  [0.0, 'summary - host_location'],
#  [0.0, 'summary - host_listings_count'],
#  [0.0, 'summary - host_is_superhost'],
#  [0.0, 'summary - host_identity_verified'],
#  [0.0, 'summary - host_id'],
#  [0.0, 'summary - host_has_profile_pic'],
#  [0.0, 'summary - host_about'],
#  [0.0, 'summary - has_availability'],
#  [0.0, 'summary - guests_included'],
#  [0.0, 'summary - first_review'],
#  [0.0, 'summary - extra_people'],
#  [0.0, 'summary - experiences_offered'],
#  [0.0, 'summary - country_code'],
#  [0.0, 'summary - country'],
#  [0.0, 'summary - cleaning_fee'],
#  [0.0, 'summary - city'],
#  [0.0, 'summary - cancellation_policy'],
#  [0.0, 'summary - calendar_updated'],
#  [0.0, 'summary - calendar_last_scraped'],
#  [0.0, 'summary - calculated_host_listings_count_shared_rooms'],
#  [0.0, 'summary - calculated_host_listings_count_private_rooms'],
#  [0.0, 'summary - calculated_host_listings_count_entire_homes'],
#  [0.0, 'summary - calculated_host_listings_count'],
#  [0.0, 'summary - beds'],
#  [0.0, 'summary - bedrooms'],
#  [0.0, 'summary - bed_type'],
#  [0.0, 'summary - bathrooms'],
#  [0.0, 'summary - availability_90'],
#  [0.0, 'summary - availability_60'],
#  [0.0, 'summary - availability_365'],
#  [0.0, 'summary - availability_30'],
#  [0.0, 'summary - amenities'],
#  [0.0, 'summary - accommodates'],
#  [0.0, 'street - zipcode'],
#  [0.0, 'street - weekly_price'],
#  [0.0, 'street - state'],
#  [0.0, 'street - security_deposit'],
#  [0.0, 'street - room_type'],
#  [0.0, 'street - reviews_per_month'],
#  [0.0, 'street - review_scores_value'],
#  [0.0, 'street - review_scores_rating'],
#  [0.0, 'street - review_scores_location'],
#  [0.0, 'street - review_scores_communication'],
#  [0.0, 'street - review_scores_cleanliness'],
#  [0.0, 'street - review_scores_checkin'],
#  [0.0, 'street - review_scores_accuracy'],
#  [0.0, 'street - requires_license'],
#  [0.0, 'street - require_guest_profile_picture'],
#  [0.0, 'street - require_guest_phone_verification'],
#  [0.0, 'street - property_type'],
#  [0.0, 'street - price'],
#  [0.0, 'street - number_of_reviews_ltm'],
#  [0.0, 'street - number_of_reviews'],
#  [0.0, 'street - neighbourhood_group_cleansed'],
#  [0.0, 'street - neighbourhood_cleansed'],
#  [0.0, 'street - neighbourhood'],
#  [0.0, 'street - monthly_price'],
#  [0.0, 'street - minimum_nights_avg_ntm'],
#  [0.0, 'street - minimum_nights'],
#  [0.0, 'street - minimum_minimum_nights'],
#  [0.0, 'street - minimum_maximum_nights'],
#  [0.0, 'street - maximum_nights_avg_ntm'],
#  [0.0, 'street - maximum_nights'],
#  [0.0, 'street - maximum_minimum_nights'],
#  [0.0, 'street - maximum_maximum_nights'],
#  [0.0, 'street - market'],
#  [0.0, 'street - longitude'],
#  [0.0, 'street - license'],
#  [0.0, 'street - latitude'],
#  [0.0, 'street - last_review'],
#  [0.0, 'street - is_location_exact'],
#  [0.0, 'street - is_business_travel_ready'],
#  [0.0, 'street - instant_bookable'],
#  [0.0, 'street - has_availability'],
#  [0.0, 'street - guests_included'],
#  [0.0, 'street - first_review'],
#  [0.0, 'street - extra_people'],
#  [0.0, 'street - country_code'],
#  [0.0, 'street - country'],
#  [0.0, 'street - cleaning_fee'],
#  [0.0, 'street - city'],
#  [0.0, 'street - cancellation_policy'],
#  [0.0, 'street - calendar_updated'],
#  [0.0, 'street - calendar_last_scraped'],
#  [0.0, 'street - calculated_host_listings_count_shared_rooms'],
#  [0.0, 'street - calculated_host_listings_count_private_rooms'],
#  [0.0, 'street - calculated_host_listings_count_entire_homes'],
#  [0.0, 'street - calculated_host_listings_count'],
#  [0.0, 'street - beds'],
#  [0.0, 'street - bedrooms'],
#  [0.0, 'street - bed_type'],
#  [0.0, 'street - bathrooms'],
#  [0.0, 'street - availability_90'],
#  [0.0, 'street - availability_60'],
#  [0.0, 'street - availability_365'],
#  [0.0, 'street - availability_30'],
#  [0.0, 'street - amenities'],
#  [0.0, 'street - accommodates'],
#  ...]

# %%
# drop primarily missing columns

listings = listings.drop(columns = ['calendar_last_scraped', 'requires_license', 'host_total_listings_count', 'requires_license', 'has_availability'])
repeating_cols(listings)
# Out:
# [[98.63359048051228,
#   'is_business_travel_ready - require_guest_profile_picture'],
#  [98.44703272323905, 'maximum_nights - maximum_maximum_nights'],
#  [98.19996974739071, 'minimum_maximum_nights - maximum_nights_avg_ntm'],
#  [98.16467503655524, 'minimum_maximum_nights - maximum_maximum_nights'],
#  [98.16467503655524, 'maximum_maximum_nights - maximum_nights_avg_ntm'],
#  [97.53441234306459, 'maximum_nights - minimum_maximum_nights'],
#  [97.51424393687289,
#   'require_guest_profile_picture - require_guest_phone_verification'],
#  [97.23188625018908, 'maximum_nights - maximum_nights_avg_ntm'],
#  [96.86885493873847, 'city - market'],
#  [96.51086572883578,
#   'is_business_travel_ready - require_guest_phone_verification'],
#  [87.49558816114556, 'minimum_nights - minimum_minimum_nights'],
#  [81.16270861695153, 'host_is_superhost - is_business_travel_ready'],
#  [80.93581404729491, 'host_is_superhost - require_guest_profile_picture'],
#  [79.86688851913478, 'host_is_superhost - require_guest_phone_verification'],
#  [79.00973125598749, 'minimum_nights - maximum_minimum_nights'],
#  [77.7290374628145, 'minimum_nights - minimum_nights_avg_ntm'],
#  [76.09035445973882, 'maximum_minimum_nights - minimum_nights_avg_ntm'],
#  [74.92562900216811, 'minimum_minimum_nights - minimum_nights_avg_ntm'],
#  [73.06509353098372, 'minimum_minimum_nights - maximum_minimum_nights'],
#  [67.13054000907577,
#   'host_identity_verified - require_guest_phone_verification'],
#  [67.0952452982403, 'host_has_profile_pic - is_location_exact'],
#  [66.58599304189985, 'host_identity_verified - require_guest_profile_picture'],
#  [66.34901426914737, 'host_identity_verified - is_business_travel_ready'],
#  [65.4918570060001, 'host_listings_count - calculated_host_listings_count'],
#  [64.82629960167398, 'host_is_superhost - host_identity_verified'],
#  [59.18418796954571, 'review_scores_checkin - review_scores_communication'],
#  [56.879947562143904, 'neighbourhood - neighbourhood_group_cleansed'],
#  [56.219432259365696, 'bedrooms - guests_included'],
#  [56.03791660364039, 'bedrooms - beds'],
#  [55.95724297887359, 'host_has_profile_pic - instant_bookable'],
#  [53.49165532193818, 'bathrooms - bedrooms'],
#  [52.54374023092825, 'review_scores_accuracy - review_scores_communication'],
#  [52.21600363031311, 'beds - guests_included'],
#  [51.752130287903995, 'review_scores_accuracy - review_scores_checkin'],
#  [50.542025916401954, 'number_of_reviews - number_of_reviews_ltm'],
#  [49.77562648111733, 'review_scores_communication - review_scores_location'],
#  [49.30166893561236, 'review_scores_accuracy - review_scores_cleanliness'],
#  [49.27141632632481, 'bathrooms - guests_included'],
#  [49.03947965512025, 'review_scores_checkin - review_scores_location'],
#  [48.64619573438209, 'is_location_exact - instant_bookable'],
#  [48.13190137649372, 'host_identity_verified - is_location_exact'],
#  [47.77895426813896,
#   'calculated_host_listings_count_entire_homes - calculated_host_listings_count_shared_rooms'],
#  [47.74870165885141,
#   'calculated_host_listings_count - calculated_host_listings_count_private_rooms'],
#  [46.2663238037614, 'review_scores_accuracy - review_scores_location'],
#  [44.74865123783593, 'host_is_superhost - instant_bookable'],
#  [44.44108304341249, 'review_scores_accuracy - review_scores_value'],
#  [44.37049362174154,
#   'review_scores_cleanliness - review_scores_communication'],
#  [44.309988403166436, 'review_scores_cleanliness - review_scores_checkin'],
#  [43.95199919326375, 'instant_bookable - require_guest_phone_verification'],
#  [43.87132556849695, 'instant_bookable - is_business_travel_ready'],
#  [43.81586245146977, 'review_scores_cleanliness - review_scores_value'],
#  [43.78560984218222,
#   'calculated_host_listings_count_private_rooms - calculated_host_listings_count_shared_rooms'],
#  [43.654515201936164,
#   'calculated_host_listings_count - calculated_host_listings_count_entire_homes'],
#  [43.57384157716936, 'instant_bookable - require_guest_profile_picture'],
#  [41.909948066354055, 'host_is_superhost - is_location_exact'],
#  [41.7183482075329, 'bathrooms - beds'],
#  [41.18892754500076, 'host_identity_verified - instant_bookable'],
#  [40.72505420259164, 'review_scores_cleanliness - review_scores_location'],
#  [39.580497151212626,
#   'host_listings_count - calculated_host_listings_count_private_rooms'],
#  [36.595573034840925, 'review_scores_communication - review_scores_value'],
#  [35.8896788181314, 'review_scores_checkin - review_scores_value'],
#  [35.30479503857208, 'review_scores_location - review_scores_value'],
#  [35.113195179750925, 'is_location_exact - require_guest_phone_verification'],
#  [33.68123834014017, 'host_has_profile_pic - host_identity_verified'],
#  [33.61569102001714, 'is_location_exact - require_guest_profile_picture'],
#  [32.692986436746835, 'is_location_exact - is_business_travel_ready'],
#  [31.054303433671155,
#   'number_of_reviews_ltm - calculated_host_listings_count_shared_rooms'],
#  [29.551757172389454, 'guests_included - calculated_host_listings_count'],
#  [29.309736298089046, 'bathrooms - minimum_minimum_nights'],
#  [29.188725860938842, 'bathrooms - calculated_host_listings_count'],
#  [28.55342106590027, 'bedrooms - minimum_minimum_nights'],
#  [27.948368880149243, 'bedrooms - calculated_host_listings_count'],
#  [27.44920082690465, 'bedrooms - minimum_nights'],
#  [27.187011546412542, 'host_neighbourhood - neighbourhood'],
#  [26.869359148893256, 'accommodates - guests_included'],
#  [26.612211969949072, 'availability_90 - availability_365'],
#  [26.55170675137397, 'availability_60 - availability_90'],
#  [26.430696314223766,
#   'availability_30 - calculated_host_listings_count_shared_rooms'],
#  [26.420612111127916, 'beds - calculated_host_listings_count'],
#  [26.057580799677304, 'host_listings_count - guests_included'],
#  [25.659254777391215,
#   'bedrooms - calculated_host_listings_count_private_rooms'],
#  [25.45757071547421, 'host_listings_count - bathrooms'],
#  [25.427318106186657, 'bathrooms - minimum_nights'],
#  [25.155044622598698, 'guests_included - minimum_minimum_nights'],
#  [25.013865779256793, 'host_listings_count - bedrooms'],
#  [24.691171280189582, 'accommodates - beds'],
#  [24.4743609136288,
#   'guests_included - calculated_host_listings_count_private_rooms'],
#  [24.096203297534412, 'guests_included - minimum_nights'],
#  [23.7533403922755, 'host_listings_count - beds'],
#  [23.728129884535875,
#   'host_listings_count - calculated_host_listings_count_entire_homes'],
#  [23.22896183129128, 'beds - calculated_host_listings_count_private_rooms'],
#  [23.178540815812028, 'availability_30 - availability_60'],
#  [22.96677255079917, 'beds - minimum_nights'],
#  [22.91635153531992, 'beds - minimum_minimum_nights'],
#  [22.886098926032368,
#   'bathrooms - calculated_host_listings_count_private_rooms'],
#  [22.744920082690463,
#   'number_of_reviews - calculated_host_listings_count_shared_rooms'],
#  [21.88272071799526, 'guests_included - maximum_minimum_nights'],
#  [21.529773609640497, 'beds - maximum_minimum_nights'],
#  [21.43397368022992, 'bedrooms - maximum_minimum_nights'],
#  [21.207079110573286, 'bedrooms - minimum_nights_avg_ntm'],
#  [20.1079009731256, 'guests_included - minimum_nights_avg_ntm'],
#  [19.608732919881007, 'accommodates - maximum_minimum_nights'],
#  [18.98855442948621, 'availability_30 - availability_90'],
#  [18.857459789240156, 'host_is_superhost - host_has_profile_pic'],
#  [18.670902031966925, 'beds - minimum_nights_avg_ntm'],
#  [18.41375485302274,
#   'availability_60 - calculated_host_listings_count_shared_rooms'],
#  [18.312912822064238,
#   'availability_30 - calculated_host_listings_count_entire_homes'],
#  [18.166691877174408, 'bathrooms - minimum_nights_avg_ntm'],
#  [18.09106035395553, 'summary - description'],
#  [17.919628901326075,
#   'number_of_reviews_ltm - calculated_host_listings_count_entire_homes'],
#  [17.728029042504918, 'bathrooms - maximum_minimum_nights'],
#  [17.667523823929816, 'accommodates - minimum_nights'],
#  [17.48600816820451, 'availability_60 - availability_365'],
#  [17.405334543437707, 'accommodates - minimum_minimum_nights'],
#  [16.467503655523622,
#   'minimum_minimum_nights - calculated_host_listings_count'],
#  [16.175061765743962, 'accommodates - minimum_nights_avg_ntm'],
#  [16.119598648716785, 'accommodates - calculated_host_listings_count'],
#  [15.857409368224676,
#   'availability_90 - calculated_host_listings_count_shared_rooms'],
#  [15.68597791559522,
#   'number_of_reviews_ltm - calculated_host_listings_count_private_rooms'],
#  [15.660767407855595, 'minimum_nights - calculated_host_listings_count'],
#  [15.277567690213282, 'host_listings_count - accommodates'],
#  [15.277567690213282, 'availability_30 - number_of_reviews_ltm'],
#  [15.146473049967227, 'host_listings_count - minimum_minimum_nights'],
#  [14.990167901981547,
#   'maximum_minimum_nights - calculated_host_listings_count'],
#  [14.65234709827056, 'host_location - country_code'],
#  [14.51621035647658, 'host_listings_count - minimum_nights'],
#  [14.395199919326377,
#   'accommodates - calculated_host_listings_count_private_rooms'],
#  [14.18343165431352, 'accommodates - bedrooms'],
#  [14.158221146573894,
#   'minimum_minimum_nights - calculated_host_listings_count_private_rooms'],
#  [14.087631724902941,
#   'availability_60 - calculated_host_listings_count_entire_homes'],
#  [14.072505420259166,
#   'minimum_nights_avg_ntm - calculated_host_listings_count'],
#  [14.047294912519536, 'host_listings_count - maximum_minimum_nights'],
#  [13.890989764533856,
#   'number_of_reviews - calculated_host_listings_count_private_rooms'],
#  [13.870821358342155, 'accommodates - bathrooms'],
#  [13.805274038219128, 'availability_30 - availability_365'],
#  [13.482579539151917,
#   'minimum_nights - calculated_host_listings_count_private_rooms'],
#  [13.069127212222053, 'host_listings_count - minimum_nights_avg_ntm'],
#  [12.83214843946957,
#   'maximum_minimum_nights - calculated_host_listings_count_private_rooms'],
#  [12.489285534210659,
#   'minimum_nights_avg_ntm - calculated_host_listings_count_private_rooms'],
#  [12.433822417183482,
#   'availability_90 - calculated_host_listings_count_entire_homes'],
#  [12.09095951192457, 'availability_60 - number_of_reviews_ltm'],
#  [12.035496394897393,
#   'number_of_reviews - calculated_host_listings_count_entire_homes'],
#  [11.909443856199264,
#   'availability_365 - calculated_host_listings_count_shared_rooms'],
#  [11.753138708213584,
#   'availability_30 - calculated_host_listings_count_private_rooms'],
#  [10.911107749710078, 'availability_90 - number_of_reviews_ltm'],
#  [10.618665859930418, 'security_deposit - extra_people'],
#  [10.24050824383603,
#   'availability_365 - calculated_host_listings_count_entire_homes'],
#  [10.180003025260929,
#   'bathrooms - calculated_host_listings_count_entire_homes'],
#  [9.45898250390763, 'cleaning_fee - extra_people'],
#  [9.141330106388343, 'availability_30 - number_of_reviews'],
#  [8.843846115060758,
#   'guests_included - calculated_host_listings_count_entire_homes'],
#  [8.400141178843342, 'first_review - last_review'],
#  [8.334593858720314, 'availability_365 - number_of_reviews_ltm'],
#  [8.238793929309736, 'bedrooms - calculated_host_listings_count_entire_homes'],
#  [7.684162759037967, 'bedrooms - number_of_reviews_ltm'],
#  [7.669036454394192, 'bedrooms - number_of_reviews'],
#  [7.643825946654566, 'host_neighbourhood - neighbourhood_cleansed'],
#  [7.467352392477185, 'guests_included - number_of_reviews'],
#  [7.371552463066607, 'guests_included - number_of_reviews_ltm'],
#  [7.255584127464328, 'bathrooms - number_of_reviews_ltm'],
#  [7.210205213533001, 'host_location - street'],
#  [6.993394846972217, 'bathrooms - number_of_reviews'],
#  [6.574900418494428, 'availability_60 - number_of_reviews'],
#  [6.3833005596732715, 'neighbourhood - neighbourhood_cleansed'],
#  [6.348005848837795, 'beds - number_of_reviews'],
#  [6.247163817879292, 'bedrooms - availability_30'],
#  [6.1765743962083395, 'beds - number_of_reviews_ltm'],
#  [6.171532294660414, 'beds - calculated_host_listings_count_entire_homes'],
#  [5.889174607976605,
#   'availability_60 - calculated_host_listings_count_private_rooms'],
#  [5.722785256895073, 'availability_90 - number_of_reviews'],
#  [5.5816064135531684, 'host_listings_count - number_of_reviews'],
#  [5.571522210457318, 'minimum_minimum_nights - availability_30'],
#  [5.505974890334291, 'beds - availability_30'],
#  [5.445469671759189, 'guests_included - availability_30'],
#  [5.430343367115413, 'bathrooms - availability_30'],
#  [5.334543437704835, 'host_listings_count - number_of_reviews_ltm'],
#  [5.294206625321434, 'minimum_nights - availability_30'],
#  [5.284122422225583, 'maximum_minimum_nights - availability_30'],
#  [5.233701406746332, 'state - market'],
#  [5.057227852568951, 'accommodates - number_of_reviews'],
#  [5.042101547925175, 'accommodates - availability_30'],
#  [4.956385821610447, 'city - state'],
#  [4.825291181364393, 'accommodates - number_of_reviews_ltm'],
#  [4.517722986940957, 'number_of_reviews_ltm - reviews_per_month'],
#  [4.517722986940957, 'number_of_reviews - reviews_per_month'],
#  [4.497554580749257, 'number_of_reviews - calculated_host_listings_count'],
#  [4.497554580749257, 'minimum_minimum_nights - number_of_reviews_ltm'],
#  [4.487470377653406,
#   'availability_90 - calculated_host_listings_count_private_rooms'],
#  [4.472344073009631, 'minimum_minimum_nights - number_of_reviews'],
#  [4.396712549790753, 'security_deposit - cleaning_fee'],
#  [4.366459940503202, 'minimum_nights - number_of_reviews'],
#  [4.245449503352997, 'host_neighbourhood - neighbourhood_group_cleansed'],
#  [4.235365300257147, 'number_of_reviews_ltm - calculated_host_listings_count'],
#  [4.215196894065446, 'minimum_nights - number_of_reviews_ltm'],
#  [4.109312761559018, 'availability_30 - calculated_host_listings_count'],
#  [4.099228558463167, 'host_listings_count - availability_30'],
#  [4.084102253819392, 'minimum_nights_avg_ntm - availability_30'],
#  [3.9227550042857864, 'availability_365 - number_of_reviews'],
#  [3.8672918872586095, 'maximum_minimum_nights - number_of_reviews'],
#  [3.821912973327283, 'bedrooms - calculated_host_listings_count_shared_rooms'],
#  [3.8017445671355823,
#   'minimum_minimum_nights - calculated_host_listings_count_entire_homes'],
#  [3.6958604346291537,
#   'host_has_profile_pic - require_guest_phone_verification'],
#  [3.680734129985378, 'maximum_minimum_nights - number_of_reviews_ltm'],
#  [3.352997529370241, 'minimum_nights_avg_ntm - number_of_reviews'],
#  [3.262239701507588,
#   'minimum_nights - calculated_host_listings_count_entire_homes'],
#  [3.1008924519739827, 'minimum_nights_avg_ntm - number_of_reviews_ltm'],
#  [3.080724045782282,
#   'maximum_minimum_nights - calculated_host_listings_count_entire_homes'],
#  [3.050471436494731,
#   'accommodates - calculated_host_listings_count_entire_homes'],
#  [2.556345484798064,
#   'host_listings_count - calculated_host_listings_count_shared_rooms'],
#  [2.5109665708667372, 'street - smart_location'],
#  [2.384914032168608,
#   'minimum_nights_avg_ntm - calculated_host_listings_count_entire_homes'],
#  [2.3748298290727576, 'availability_30 - review_scores_value'],
#  [2.3193667120455808, 'bedrooms - availability_60'],
#  [2.29919830585388, 'availability_30 - review_scores_cleanliness'],
#  [2.238693087278778, 'availability_30 - review_scores_location'],
#  [2.238693087278778, 'availability_30 - review_scores_accuracy'],
#  [2.178187868703676,
#   'availability_365 - calculated_host_listings_count_private_rooms'],
#  [2.1479352594161245, 'availability_30 - review_scores_communication'],
#  [2.1428931578681993, 'availability_30 - review_scores_checkin'],
#  [2.1126405485806483, 'guests_included - reviews_per_month'],
#  [2.072303736197247, 'bathrooms - reviews_per_month'],
#  [2.0672616346493218, 'accommodates - availability_60'],
#  [2.0218827207179952, 'space - description'],
#  [1.9966722129783694, 'beds - availability_60'],
#  [1.9714617052387435, 'bedrooms - reviews_per_month'],
#  [1.865577572732315, 'guests_included - availability_60'],
#  [1.7647355417738115, 'availability_60 - calculated_host_listings_count'],
#  [1.7596934402258864, 'host_listings_count - availability_60'],
#  [1.7546513386779607, 'minimum_nights - availability_60'],
#  [1.7546513386779607, 'availability_60 - review_scores_location'],
#  [1.7546513386779607, 'availability_60 - review_scores_communication'],
#  [1.7445671355821104, 'availability_60 - review_scores_value'],
#  [1.729440830938335, 'beds - reviews_per_month'],
#  [1.7092724247466342, 'maximum_minimum_nights - availability_60'],
#  [1.704230323198709, 'availability_60 - review_scores_checkin'],
#  [1.6790198154590832, 'availability_60 - review_scores_cleanliness'],
#  [1.673977713911158, 'minimum_minimum_nights - availability_60'],
#  [1.6638935108153077, 'availability_60 - review_scores_accuracy'],
#  [1.6285987999798315, 'number_of_reviews_ltm - review_scores_checkin'],
#  [1.6285987999798315, 'bathrooms - availability_60'],
#  [1.6185145968839811, 'number_of_reviews - review_scores_checkin'],
#  [1.5781777845005798, 'number_of_reviews - review_scores_location'],
#  [1.5781777845005798, 'host_has_profile_pic - require_guest_profile_picture'],
#  [1.5731356829526546, 'number_of_reviews - review_scores_value'],
#  [1.552967276760954, 'number_of_reviews_ltm - review_scores_location'],
#  [1.5479251752130287, 'number_of_reviews_ltm - review_scores_value'],
#  [1.5479251752130287, 'number_of_reviews - review_scores_cleanliness'],
#  [1.527756769021328, 'number_of_reviews - review_scores_communication'],
#  [1.527756769021328,
#   'calculated_host_listings_count_entire_homes - calculated_host_listings_count_private_rooms'],
#  [1.5075883628296274, 'number_of_reviews_ltm - review_scores_cleanliness'],
#  [1.5025462612817022, 'number_of_reviews_ltm - review_scores_communication'],
#  [1.4369989411586748, 'minimum_minimum_nights - reviews_per_month'],
#  [1.411788433419049, 'minimum_nights_avg_ntm - availability_60'],
#  [1.3966621287752734, 'number_of_reviews - review_scores_accuracy'],
#  [1.3512832148439469, 'number_of_reviews_ltm - review_scores_accuracy'],
#  [1.3411990117480965, 'bedrooms - availability_90'],
#  [1.3159885040084707, 'minimum_nights - reviews_per_month'],
#  [1.2201885745978924, 'calculated_host_listings_count - reviews_per_month'],
#  [1.1949780668582666, 'accommodates - review_scores_cleanliness'],
#  [1.1899359653103414, 'price - cleaning_fee'],
#  [1.1899359653103414, 'accommodates - review_scores_value'],
#  [1.1344728482831645, 'host_listings_count - availability_90'],
#  [1.1243886451873142, 'maximum_minimum_nights - reviews_per_month'],
#  [1.1092623405435387, 'accommodates - reviews_per_month'],
#  [1.0991781374476883, 'minimum_nights_avg_ntm - reviews_per_month'],
#  [1.0790097312559876, 'host_listings_count - review_scores_value'],
#  [1.0739676297080623, 'accommodates - review_scores_accuracy'],
#  [1.068925528160137, 'review_scores_value - calculated_host_listings_count'],
#  [1.068925528160137, 'minimum_maximum_nights - review_scores_checkin'],
#  [1.063883426612212, 'beds - calculated_host_listings_count_shared_rooms'],
#  [1.0437150204205112, 'maximum_nights_avg_ntm - review_scores_checkin'],
#  [1.038672918872586, 'availability_90 - review_scores_location'],
#  [1.0336308173246609, 'minimum_maximum_nights - review_scores_communication'],
#  [1.0285887157767357, 'maximum_nights - review_scores_checkin'],
#  [1.0285887157767357, 'maximum_maximum_nights - review_scores_checkin'],
#  [1.0285887157767357, 'accommodates - review_scores_checkin'],
#  [1.0235466142288105, 'minimum_maximum_nights - review_scores_location'],
#  [1.0235466142288105, 'bathrooms - availability_90'],
#  [1.0235466142288105, 'availability_90 - calculated_host_listings_count'],
#  [1.0185045126808854, 'maximum_nights_avg_ntm - review_scores_location'],
#  [1.0134624111329602, 'maximum_nights_avg_ntm - review_scores_communication'],
#  [1.008420309585035, 'host_listings_count - reviews_per_month'],
#  [1.008420309585035, 'host_listings_count - review_scores_cleanliness'],
#  [1.008420309585035, 'host_listings_count - review_scores_accuracy'],
#  [0.9983361064891847, 'maximum_nights - review_scores_location'],
#  [0.9983361064891847, 'maximum_nights - review_scores_communication'],
#  [0.9983361064891847, 'maximum_maximum_nights - review_scores_location'],
#  [0.9983361064891847, 'maximum_maximum_nights - review_scores_communication'],
#  [0.9983361064891847, 'guests_included - availability_90'],
#  [0.9731255987495588, 'availability_90 - review_scores_checkin'],
#  [0.9680834972016337, 'host_listings_count - review_scores_communication'],
#  [0.9630413956537085,
#   'review_scores_accuracy - calculated_host_listings_count'],
#  [0.9630413956537085, 'minimum_maximum_nights - review_scores_accuracy'],
#  [0.9630413956537085, 'beds - availability_90'],
#  [0.9579992941057833, 'accommodates - review_scores_communication'],
#  [0.9529571925578582, 'maximum_nights_avg_ntm - review_scores_accuracy'],
#  [0.9529571925578582, 'accommodates - availability_90'],
#  [0.947915091009933, 'availability_90 - review_scores_communication'],
#  [0.947915091009933, 'availability_90 - review_scores_cleanliness'],
#  [0.9378308879140826, 'accommodates - review_scores_location'],
#  [0.9327887863661575, 'maximum_nights - review_scores_accuracy'],
#  [0.9327887863661575, 'maximum_maximum_nights - review_scores_accuracy'],
#  [0.9327887863661575,
#   'calculated_host_listings_count_private_rooms - reviews_per_month'],
#  [0.917662481722382,
#   'bathrooms - calculated_host_listings_count_shared_rooms'],
#  [0.917662481722382, 'availability_90 - review_scores_accuracy'],
#  [0.9075782786265316, 'minimum_maximum_nights - review_scores_cleanliness'],
#  [0.9025361770786064, 'minimum_nights - availability_90'],
#  [0.8924519739827561, 'maximum_nights_avg_ntm - review_scores_cleanliness'],
#  [0.8874098724348309, 'minimum_minimum_nights - availability_90'],
#  [0.8722835677910552, 'maximum_nights - review_scores_cleanliness'],
#  [0.8722835677910552, 'maximum_maximum_nights - review_scores_cleanliness'],
#  [0.8521151615993545, 'maximum_minimum_nights - availability_90'],
#  [0.8521151615993545, 'availability_90 - review_scores_value'],
#  [0.8470730600514293, 'maximum_minimum_nights - minimum_maximum_nights'],
#  [0.8420309585035042,
#   'review_scores_communication - calculated_host_listings_count'],
#  [0.8420309585035042,
#   'review_scores_checkin - calculated_host_listings_count'],
#  [0.8420309585035042, 'host_listings_count - review_scores_checkin'],
#  [0.836988856955579, 'minimum_maximum_nights - minimum_nights_avg_ntm'],
#  [0.8319467554076538,
#   'review_scores_cleanliness - calculated_host_listings_count'],
#  [0.806736247668028, 'host_listings_count - review_scores_location'],
#  [0.7613573337367014,
#   'review_scores_location - calculated_host_listings_count'],
#  [0.7563152321887763, 'price - extra_people'],
#  [0.7411889275450008, 'minimum_minimum_nights - minimum_maximum_nights'],
#  [0.7361468259970756, 'minimum_nights_avg_ntm - availability_90'],
#  [0.7210205213533, 'price - security_deposit'],
#  [0.7008521151615993, 'minimum_nights - minimum_maximum_nights'],
#  [0.6958100136136741, 'bedrooms - availability_365'],
#  [0.6756416074219734, 'minimum_maximum_nights - review_scores_value'],
#  [0.6605153027781979, 'maximum_nights_avg_ntm - review_scores_value'],
#  [0.6453889981344224, 'maximum_nights - review_scores_value'],
#  [0.6453889981344224, 'maximum_maximum_nights - review_scores_value'],
#  [0.6403468965864972, 'host_location - country'],
#  [0.5899258811072455, 'last_scraped - last_review'],
#  [0.5899258811072455,
#   'guests_included - calculated_host_listings_count_shared_rooms'],
#  [0.5848837795593204,
#   'review_scores_value - calculated_host_listings_count_entire_homes'],
#  [0.57479957646347,
#   'review_scores_accuracy - calculated_host_listings_count_entire_homes'],
#  [0.5697574749155448,
#   'review_scores_location - calculated_host_listings_count_entire_homes'],
#  [0.5697574749155448, 'maximum_nights - maximum_minimum_nights'],
#  [0.5647153733676197, 'maximum_minimum_nights - maximum_nights_avg_ntm'],
#  [0.5647153733676197, 'maximum_minimum_nights - maximum_maximum_nights'],
#  [0.544546967175919,
#   'review_scores_checkin - calculated_host_listings_count_entire_homes'],
#  [0.5395048656279938,
#   'calculated_host_listings_count - calculated_host_listings_count_shared_rooms'],
#  [0.5294206625321434, 'minimum_nights - maximum_nights'],
#  [0.5243785609842182,
#   'review_scores_communication - calculated_host_listings_count_entire_homes'],
#  [0.519336459436293, 'minimum_nights - maximum_nights_avg_ntm'],
#  [0.519336459436293, 'minimum_nights - maximum_maximum_nights'],
#  [0.5092522563404427, 'maximum_nights - minimum_nights_avg_ntm'],
#  [0.5092522563404427, 'maximum_nights - minimum_minimum_nights'],
#  [0.5092522563404427,
#   'calculated_host_listings_count_entire_homes - reviews_per_month'],
#  [0.49916805324459235, 'minimum_nights_avg_ntm - maximum_nights_avg_ntm'],
#  [0.49916805324459235, 'minimum_minimum_nights - maximum_nights_avg_ntm'],
#  [0.49916805324459235, 'minimum_minimum_nights - maximum_maximum_nights'],
#  [0.49916805324459235, 'maximum_maximum_nights - minimum_nights_avg_ntm'],
#  [0.489083850148742, 'beds - review_scores_value'],
#  [0.4739575455049665,
#   'review_scores_cleanliness - calculated_host_listings_count_entire_homes'],
#  [0.458831240861191, 'bathrooms - availability_365'],
#  [0.4537891393132658, 'maximum_nights - availability_60'],
#  [0.44370493621741547, 'minimum_maximum_nights - availability_60'],
#  [0.44370493621741547, 'maximum_maximum_nights - availability_60'],
#  [0.4386628346694902, 'maximum_nights_avg_ntm - availability_60'],
#  [0.42857863157363985, 'host_listings_count - availability_365'],
#  [0.42857863157363985, 'beds - review_scores_accuracy'],
#  [0.4184944284777895, 'guests_included - review_scores_value'],
#  [0.4184944284777895, 'beds - availability_365'],
#  [0.41345232692986433, 'minimum_maximum_nights - availability_30'],
#  [0.41345232692986433, 'maximum_nights - availability_90'],
#  [0.41345232692986433, 'beds - review_scores_cleanliness'],
#  [0.41345232692986433, 'accommodates - availability_365'],
#  [0.40841022538193916, 'minimum_maximum_nights - availability_90'],
#  [0.40841022538193916, 'maximum_maximum_nights - availability_90'],
#  [0.403368123834014, 'maximum_nights_avg_ntm - availability_90'],
#  [0.403368123834014, 'guests_included - availability_365'],
#  [0.3983260222860888, 'minimum_maximum_nights - number_of_reviews_ltm'],
#  [0.39328392073816365, 'maximum_nights - availability_30'],
#  [0.3882418191902385, 'maximum_maximum_nights - availability_30'],
#  [0.3831997176423133, 'maximum_nights_avg_ntm - availability_30'],
#  [0.3831997176423133, 'beds - review_scores_communication'],
#  [0.37311551454646297, 'guests_included - review_scores_accuracy'],
#  [0.3680734129985378, 'neighbourhood_cleansed - neighbourhood_group_cleansed'],
#  [0.36303131145061257, 'beds - review_scores_checkin'],
#  [0.36303131145061257, 'availability_365 - calculated_host_listings_count'],
#  [0.3579892099026874, 'maximum_nights - number_of_reviews_ltm'],
#  [0.3579892099026874, 'guests_included - review_scores_checkin'],
#  [0.3579892099026874, 'bedrooms - minimum_maximum_nights'],
#  [0.35294710835476223, 'maximum_nights_avg_ntm - number_of_reviews_ltm'],
#  [0.35294710835476223, 'maximum_maximum_nights - number_of_reviews_ltm'],
#  [0.35294710835476223, 'guests_included - review_scores_cleanliness'],
#  [0.3428629052589119, 'minimum_nights - availability_365'],
#  [0.3428629052589119, 'minimum_maximum_nights - number_of_reviews'],
#  [0.3428629052589119, 'guests_included - review_scores_communication'],
#  [0.3378208037109867,
#   'minimum_nights - calculated_host_listings_count_shared_rooms'],
#  [0.33277870216306155, 'notes - license'],
#  [0.33277870216306155,
#   'minimum_minimum_nights - calculated_host_listings_count_shared_rooms'],
#  [0.3277366006151364, 'maximum_minimum_nights - availability_365'],
#  [0.3226944990672112, 'minimum_minimum_nights - availability_365'],
#  [0.31765239751928603, 'guests_included - review_scores_location'],
#  [0.31261029597136086,
#   'review_scores_accuracy - calculated_host_listings_count_private_rooms'],
#  [0.3075681944234357,
#   'maximum_minimum_nights - calculated_host_listings_count_shared_rooms'],
#  [0.3025260928755105, 'maximum_minimum_nights - review_scores_value'],
#  [0.29748399132758535,
#   'review_scores_value - calculated_host_listings_count_private_rooms'],
#  [0.29748399132758535, 'minimum_nights_avg_ntm - availability_365'],
#  [0.29748399132758535, 'beds - review_scores_location'],
#  [0.2924418897796602, 'availability_30 - reviews_per_month'],
#  [0.287399788231735,
#   'minimum_nights_avg_ntm - calculated_host_listings_count_shared_rooms'],
#  [0.287399788231735, 'maximum_maximum_nights - availability_365'],
#  [0.28235768668380984, 'maximum_minimum_nights - review_scores_accuracy'],
#  [0.28235768668380984, 'maximum_maximum_nights - number_of_reviews'],
#  [0.28235768668380984, 'guests_included - minimum_maximum_nights'],
#  [0.28235768668380984, 'accommodates - minimum_maximum_nights'],
#  [0.27731558513588467,
#   'review_scores_cleanliness - calculated_host_listings_count_private_rooms'],
#  [0.27731558513588467, 'minimum_maximum_nights - availability_365'],
#  [0.27731558513588467, 'maximum_nights_avg_ntm - number_of_reviews'],
#  [0.27731558513588467, 'maximum_nights_avg_ntm - availability_365'],
#  [0.27731558513588467, 'maximum_nights - number_of_reviews'],
#  [0.27731558513588467, 'maximum_nights - availability_365'],
#  [0.27731558513588467, 'availability_90 - review_scores_rating'],
#  [0.2722734835879595,
#   'accommodates - calculated_host_listings_count_shared_rooms'],
#  [0.2621892804921091, 'maximum_minimum_nights - review_scores_communication'],
#  [0.25714717894418393, 'space - access'],
#  [0.25714717894418393,
#   'review_scores_checkin - calculated_host_listings_count_private_rooms'],
#  [0.25714717894418393, 'maximum_minimum_nights - review_scores_cleanliness'],
#  [0.25210507739625876, 'summary - space'],
#  [0.25210507739625876, 'maximum_minimum_nights - review_scores_checkin'],
#  [0.24202087430040842,
#   'review_scores_communication - calculated_host_listings_count_private_rooms'],
#  [0.24202087430040842, 'notes - interaction'],
#  [0.24202087430040842, 'host_name - market'],
#  [0.23193667120455808, 'availability_365 - review_scores_cleanliness'],
#  [0.2268945696566329, 'host_name - city'],
#  [0.22185246810870773, 'beds - minimum_maximum_nights'],
#  [0.2168103665607825, 'host_listings_count - minimum_maximum_nights'],
#  [0.2168103665607825, 'availability_365 - review_scores_location'],
#  [0.2168103665607825, 'availability_365 - review_scores_checkin'],
#  [0.21176826501285734, 'host_has_profile_pic - is_business_travel_ready'],
#  [0.21176826501285734, 'availability_365 - review_scores_communication'],
#  [0.20672616346493217,
#   'minimum_maximum_nights - calculated_host_listings_count'],
#  [0.20672616346493217, 'availability_365 - review_scores_accuracy'],
#  [0.19159985882115665,
#   'review_scores_location - calculated_host_listings_count_private_rooms'],
#  [0.19159985882115665, 'notes - house_rules'],
#  [0.19159985882115665, 'notes - access'],
#  [0.18151565572530629, 'space - neighborhood_overview'],
#  [0.18151565572530629,
#   'minimum_maximum_nights - calculated_host_listings_count_private_rooms'],
#  [0.18151565572530629, 'availability_365 - review_scores_value'],
#  [0.18151565572530629, 'availability_365 - review_scores_rating'],
#  [0.18151565572530629, 'accommodates - maximum_nights'],
#  [0.17647355417738111, 'minimum_nights - review_scores_cleanliness'],
#  [0.17647355417738111, 'maximum_minimum_nights - review_scores_location'],
#  [0.17647355417738111, 'accommodates - maximum_nights_avg_ntm'],
#  [0.17647355417738111, 'accommodates - maximum_maximum_nights'],
#  [0.17143145262945594, 'minimum_nights - review_scores_accuracy'],
#  [0.16638935108153077, 'bedrooms - review_scores_value'],
#  [0.16638935108153077, 'bathrooms - minimum_maximum_nights'],
#  [0.15630514798568043, 'number_of_reviews - review_scores_rating'],
#  [0.15630514798568043, 'minimum_minimum_nights - review_scores_cleanliness'],
#  [0.15630514798568043, 'maximum_nights - review_scores_rating'],
#  [0.15630514798568043, 'maximum_maximum_nights - review_scores_rating'],
#  [0.15126304643775526, 'minimum_nights - review_scores_value'],
#  [0.15126304643775526, 'minimum_nights - review_scores_communication'],
#  [0.15126304643775526, 'minimum_maximum_nights - review_scores_rating'],
#  [0.15126304643775526, 'maximum_nights_avg_ntm - review_scores_rating'],
#  [0.1462209448898301, 'minimum_minimum_nights - review_scores_accuracy'],
#  [0.14117884334190492, 'minimum_nights - review_scores_checkin'],
#  [0.14117884334190492, 'minimum_minimum_nights - review_scores_communication'],
#  [0.14117884334190492, 'host_listings_count - maximum_nights_avg_ntm'],
#  [0.14117884334190492, 'host_listings_count - maximum_nights'],
#  [0.14117884334190492, 'host_listings_count - maximum_maximum_nights'],
#  [0.13613674179397975, 'neighborhood_overview - notes'],
#  [0.13613674179397975, 'minimum_nights_avg_ntm - review_scores_communication'],
#  [0.13613674179397975, 'minimum_nights_avg_ntm - review_scores_cleanliness'],
#  [0.13613674179397975, 'minimum_minimum_nights - review_scores_checkin'],
#  [0.13613674179397975,
#   'maximum_nights_avg_ntm - calculated_host_listings_count'],
#  [0.13613674179397975, 'maximum_nights - calculated_host_listings_count'],
#  [0.13613674179397975,
#   'maximum_maximum_nights - calculated_host_listings_count'],
#  [0.13613674179397975, 'bedrooms - review_scores_accuracy'],
#  [0.12605253869812938, 'neighborhood_overview - transit'],
#  [0.12605253869812938, 'minimum_nights_avg_ntm - review_scores_accuracy'],
#  [0.12101043715020421, 'minimum_nights_avg_ntm - review_scores_checkin'],
#  [0.12101043715020421, 'minimum_minimum_nights - review_scores_value'],
#  [0.11596833560227904, 'minimum_nights_avg_ntm - review_scores_value'],
#  [0.11596833560227904, 'bedrooms - review_scores_cleanliness'],
#  [0.10588413250642867, 'description - notes'],
#  [0.10588413250642867, 'bedrooms - review_scores_communication'],
#  [0.10588413250642867, 'bedrooms - review_scores_checkin'],
#  [0.1008420309585035, 'minimum_minimum_nights - review_scores_location'],
#  [0.1008420309585035,
#   'minimum_maximum_nights - calculated_host_listings_count_entire_homes'],
#  [0.1008420309585035, 'access - interaction'],
#  [0.09579992941057833, 'name - summary'],
#  [0.09579992941057833, 'bathrooms - review_scores_value'],
#  [0.09075782786265314, 'minimum_nights - review_scores_location'],
#  [0.09075782786265314,
#   'maximum_nights - calculated_host_listings_count_private_rooms'],
#  [0.09075782786265314, 'bedrooms - maximum_nights'],
#  [0.08571572631472797, 'space - notes'],
#  [0.08571572631472797,
#   'review_scores_rating - calculated_host_listings_count_entire_homes'],
#  [0.08571572631472797, 'neighborhood_overview - access'],
#  [0.08571572631472797,
#   'maximum_nights_avg_ntm - calculated_host_listings_count_private_rooms'],
#  [0.08571572631472797,
#   'maximum_maximum_nights - calculated_host_listings_count_private_rooms'],
#  [0.08571572631472797, 'description - neighborhood_overview'],
#  [0.08571572631472797, 'beds - maximum_nights'],
#  [0.0806736247668028, 'review_scores_rating - calculated_host_listings_count'],
#  [0.0806736247668028, 'neighbourhood_group_cleansed - city'],
#  [0.0806736247668028, 'guests_included - maximum_nights'],
#  [0.0806736247668028, 'beds - maximum_nights_avg_ntm'],
#  [0.0806736247668028, 'beds - maximum_maximum_nights'],
#  [0.0806736247668028, 'bedrooms - maximum_nights_avg_ntm'],
#  [0.0806736247668028, 'bedrooms - maximum_maximum_nights'],
#  [0.07563152321887763, 'neighbourhood - city'],
#  [0.07563152321887763, 'bedrooms - review_scores_location'],
#  [0.07563152321887763, 'bathrooms - maximum_nights_avg_ntm'],
#  [0.07563152321887763, 'bathrooms - maximum_nights'],
#  [0.07563152321887763, 'bathrooms - maximum_maximum_nights'],
#  [0.07058942167095246, 'state - country'],
#  [0.07058942167095246, 'guests_included - maximum_nights_avg_ntm'],
#  [0.07058942167095246, 'guests_included - maximum_maximum_nights'],
#  [0.07058942167095246, 'description - access'],
#  [0.07058942167095246, 'bathrooms - review_scores_communication'],
#  [0.07058942167095246, 'bathrooms - review_scores_cleanliness'],
#  [0.06554732012302728, 'minimum_nights_avg_ntm - review_scores_location'],
#  [0.06554732012302728, 'bathrooms - review_scores_accuracy'],
#  [0.06554732012302728, 'availability_60 - reviews_per_month'],
#  [0.060505218575102104, 'summary - neighborhood_overview'],
#  [0.060505218575102104,
#   'minimum_maximum_nights - calculated_host_listings_count_shared_rooms'],
#  [0.060505218575102104,
#   'maximum_nights - calculated_host_listings_count_shared_rooms'],
#  [0.060505218575102104, 'last_scraped - first_review'],
#  [0.05042101547925175, 'weekly_price - security_deposit'],
#  [0.05042101547925175, 'transit - access'],
#  [0.05042101547925175,
#   'maximum_nights_avg_ntm - calculated_host_listings_count_entire_homes'],
#  [0.05042101547925175,
#   'maximum_nights - calculated_host_listings_count_entire_homes'],
#  [0.05042101547925175,
#   'maximum_maximum_nights - calculated_host_listings_count_entire_homes'],
#  [0.05042101547925175, 'availability_60 - review_scores_rating'],
#  [0.04537891393132657, 'transit - interaction'],
#  [0.04537891393132657, 'summary - access'],
#  [0.04537891393132657, 'notes - transit'],
#  [0.04537891393132657, 'host_since - first_review'],
#  [0.0403368123834014, 'minimum_maximum_nights - reviews_per_month'],
#  [0.03529471083547623, 'summary - notes'],
#  [0.03529471083547623, 'neighborhood_overview - neighbourhood_group_cleansed'],
#  [0.03529471083547623, 'maximum_nights_avg_ntm - reviews_per_month'],
#  [0.03529471083547623, 'maximum_nights - reviews_per_month'],
#  [0.03529471083547623, 'maximum_maximum_nights - reviews_per_month'],
#  [0.03529471083547623, 'host_about - market'],
#  [0.03529471083547623, 'host_about - city'],
#  [0.03529471083547623,
#   'calculated_host_listings_count_shared_rooms - reviews_per_month'],
#  [0.03529471083547623, 'bathrooms - review_scores_checkin'],
#  [0.03529471083547623, 'availability_90 - reviews_per_month'],
#  [0.030252609287551052, 'summary - license'],
#  [0.030252609287551052, 'space - transit'],
#  [0.030252609287551052, 'neighborhood_overview - neighbourhood'],
#  [0.030252609287551052, 'name - host_name'],
#  [0.030252609287551052, 'monthly_price - security_deposit'],
#  [0.030252609287551052, 'interaction - house_rules'],
#  [0.030252609287551052, 'availability_365 - reviews_per_month'],
#  [0.025210507739625874, 'name - description'],
#  [0.025210507739625874, 'description - transit'],
#  [0.025210507739625874, 'access - host_about'],
#  [0.0201684061917007, 'space - interaction'],
#  [0.0201684061917007, 'review_scores_value - reviews_per_month'],
#  [0.0201684061917007, 'review_scores_location - reviews_per_month'],
#  [0.0201684061917007, 'review_scores_communication - reviews_per_month'],
#  [0.0201684061917007,
#   'review_scores_communication - calculated_host_listings_count_shared_rooms'],
#  [0.0201684061917007,
#   'review_scores_cleanliness - calculated_host_listings_count_shared_rooms'],
#  [0.0201684061917007,
#   'review_scores_checkin - calculated_host_listings_count_shared_rooms'],
#  [0.0201684061917007, 'maximum_minimum_nights - review_scores_rating'],
#  [0.0201684061917007, 'host_since - last_review'],
#  [0.0201684061917007, 'description - interaction'],
#  [0.0201684061917007, 'bathrooms - review_scores_location'],
#  [0.015126304643775526, 'summary - interaction'],
#  [0.015126304643775526, 'space - house_rules'],
#  [0.015126304643775526,
#   'review_scores_value - calculated_host_listings_count_shared_rooms'],
#  [0.015126304643775526,
#   'review_scores_location - calculated_host_listings_count_shared_rooms'],
#  [0.015126304643775526, 'review_scores_cleanliness - reviews_per_month'],
#  [0.015126304643775526,
#   'review_scores_accuracy - calculated_host_listings_count_shared_rooms'],
#  [0.015126304643775526, 'neighborhood_overview - interaction'],
#  [0.015126304643775526, 'host_name - state'],
#  [0.015126304643775526, 'host_name - host_about'],
#  [0.015126304643775526, 'access - house_rules'],
#  [0.01008420309585035, 'summary - transit'],
#  [0.01008420309585035, 'review_scores_checkin - reviews_per_month'],
#  [0.01008420309585035, 'review_scores_accuracy - reviews_per_month'],
#  [0.01008420309585035, 'number_of_reviews_ltm - review_scores_rating'],
#  [0.01008420309585035, 'notes - market'],
#  [0.01008420309585035, 'notes - city'],
#  [0.01008420309585035, 'neighborhood_overview - neighbourhood_cleansed'],
#  [0.01008420309585035, 'name - space'],
#  [0.01008420309585035, 'minimum_nights_avg_ntm - review_scores_rating'],
#  [0.01008420309585035, 'minimum_nights - review_scores_rating'],
#  [0.01008420309585035, 'minimum_minimum_nights - review_scores_rating'],
#  [0.01008420309585035, 'host_location - market'],
#  [0.01008420309585035, 'host_location - city'],
#  [0.005042101547925175, 'zipcode - number_of_reviews_ltm'],
#  [0.005042101547925175, 'zipcode - number_of_reviews'],
#  [0.005042101547925175,
#   'zipcode - calculated_host_listings_count_shared_rooms'],
#  [0.005042101547925175,
#   'zipcode - calculated_host_listings_count_private_rooms'],
#  [0.005042101547925175, 'zipcode - bedrooms'],
#  [0.005042101547925175, 'weekly_price - monthly_price'],
#  [0.005042101547925175, 'transit - house_rules'],
#  [0.005042101547925175, 'transit - host_about'],
#  [0.005042101547925175, 'summary - house_rules'],
#  [0.005042101547925175, 'neighborhood_overview - house_rules'],
#  [0.005042101547925175, 'neighborhood_overview - host_neighbourhood'],
#  [0.005042101547925175, 'name - transit'],
#  [0.005042101547925175, 'name - notes'],
#  [0.005042101547925175, 'name - neighbourhood_group_cleansed'],
#  [0.005042101547925175, 'name - neighbourhood'],
#  [0.005042101547925175, 'name - neighborhood_overview'],
#  [0.005042101547925175, 'name - interaction'],
#  [0.005042101547925175, 'name - host_about'],
#  [0.005042101547925175, 'name - access'],
#  [0.005042101547925175,
#   'maximum_nights_avg_ntm - calculated_host_listings_count_shared_rooms'],
#  [0.005042101547925175,
#   'maximum_maximum_nights - calculated_host_listings_count_shared_rooms'],
#  [0.005042101547925175, 'interaction - require_guest_profile_picture'],
#  [0.005042101547925175, 'interaction - require_guest_phone_verification'],
#  [0.005042101547925175, 'interaction - is_location_exact'],
#  [0.005042101547925175, 'interaction - is_business_travel_ready'],
#  [0.005042101547925175, 'interaction - host_identity_verified'],
#  [0.005042101547925175, 'interaction - host_about'],
#  [0.005042101547925175, 'house_rules - host_about'],
#  [0.005042101547925175, 'host_name - property_type'],
#  [0.005042101547925175, 'host_name - neighbourhood'],
#  [0.005042101547925175, 'host_name - host_neighbourhood'],
#  [0.005042101547925175, 'host_about - country'],
#  [0.005042101547925175, 'city - zipcode'],
#  [0.005042101547925175, 'availability_30 - review_scores_rating'],
#  [0.0, 'zipcode - weekly_price'],
#  [0.0, 'zipcode - smart_location'],
#  [0.0, 'zipcode - security_deposit'],
#  [0.0, 'zipcode - room_type'],
#  [0.0, 'zipcode - reviews_per_month'],
#  [0.0, 'zipcode - review_scores_value'],
#  [0.0, 'zipcode - review_scores_rating'],
#  [0.0, 'zipcode - review_scores_location'],
#  [0.0, 'zipcode - review_scores_communication'],
#  [0.0, 'zipcode - review_scores_cleanliness'],
#  [0.0, 'zipcode - review_scores_checkin'],
#  [0.0, 'zipcode - review_scores_accuracy'],
#  [0.0, 'zipcode - require_guest_profile_picture'],
#  [0.0, 'zipcode - require_guest_phone_verification'],
#  [0.0, 'zipcode - property_type'],
#  [0.0, 'zipcode - price'],
#  [0.0, 'zipcode - monthly_price'],
#  [0.0, 'zipcode - minimum_nights_avg_ntm'],
#  [0.0, 'zipcode - minimum_nights'],
#  [0.0, 'zipcode - minimum_minimum_nights'],
#  [0.0, 'zipcode - minimum_maximum_nights'],
#  [0.0, 'zipcode - maximum_nights_avg_ntm'],
#  [0.0, 'zipcode - maximum_nights'],
#  [0.0, 'zipcode - maximum_minimum_nights'],
#  [0.0, 'zipcode - maximum_maximum_nights'],
#  [0.0, 'zipcode - market'],
#  [0.0, 'zipcode - longitude'],
#  [0.0, 'zipcode - license'],
#  [0.0, 'zipcode - latitude'],
#  [0.0, 'zipcode - last_review'],
#  [0.0, 'zipcode - is_location_exact'],
#  [0.0, 'zipcode - is_business_travel_ready'],
#  [0.0, 'zipcode - instant_bookable'],
#  [0.0, 'zipcode - guests_included'],
#  [0.0, 'zipcode - first_review'],
#  [0.0, 'zipcode - extra_people'],
#  [0.0, 'zipcode - country_code'],
#  [0.0, 'zipcode - country'],
#  [0.0, 'zipcode - cleaning_fee'],
#  [0.0, 'zipcode - cancellation_policy'],
#  [0.0, 'zipcode - calendar_updated'],
#  [0.0, 'zipcode - calculated_host_listings_count_entire_homes'],
#  [0.0, 'zipcode - calculated_host_listings_count'],
#  [0.0, 'zipcode - beds'],
#  [0.0, 'zipcode - bed_type'],
#  [0.0, 'zipcode - bathrooms'],
#  [0.0, 'zipcode - availability_90'],
#  [0.0, 'zipcode - availability_60'],
#  [0.0, 'zipcode - availability_365'],
#  [0.0, 'zipcode - availability_30'],
#  [0.0, 'zipcode - amenities'],
#  [0.0, 'zipcode - accommodates'],
#  [0.0, 'weekly_price - reviews_per_month'],
#  [0.0, 'weekly_price - review_scores_value'],
#  [0.0, 'weekly_price - review_scores_rating'],
#  [0.0, 'weekly_price - review_scores_location'],
#  [0.0, 'weekly_price - review_scores_communication'],
#  [0.0, 'weekly_price - review_scores_cleanliness'],
#  [0.0, 'weekly_price - review_scores_checkin'],
#  [0.0, 'weekly_price - review_scores_accuracy'],
#  [0.0, 'weekly_price - require_guest_profile_picture'],
#  [0.0, 'weekly_price - require_guest_phone_verification'],
#  [0.0, 'weekly_price - number_of_reviews_ltm'],
#  [0.0, 'weekly_price - number_of_reviews'],
#  [0.0, 'weekly_price - minimum_nights_avg_ntm'],
#  [0.0, 'weekly_price - minimum_nights'],
#  [0.0, 'weekly_price - minimum_minimum_nights'],
#  [0.0, 'weekly_price - minimum_maximum_nights'],
#  [0.0, 'weekly_price - maximum_nights_avg_ntm'],
#  [0.0, 'weekly_price - maximum_nights'],
#  [0.0, 'weekly_price - maximum_minimum_nights'],
#  [0.0, 'weekly_price - maximum_maximum_nights'],
#  [0.0, 'weekly_price - license'],
#  [0.0, 'weekly_price - last_review'],
#  [0.0, 'weekly_price - is_business_travel_ready'],
#  [0.0, 'weekly_price - instant_bookable'],
#  [0.0, 'weekly_price - guests_included'],
#  [0.0, 'weekly_price - first_review'],
#  [0.0, 'weekly_price - extra_people'],
#  [0.0, 'weekly_price - cleaning_fee'],
#  [0.0, 'weekly_price - cancellation_policy'],
#  [0.0, 'weekly_price - calendar_updated'],
#  [0.0, 'weekly_price - calculated_host_listings_count_shared_rooms'],
#  [0.0, 'weekly_price - calculated_host_listings_count_private_rooms'],
#  [0.0, 'weekly_price - calculated_host_listings_count_entire_homes'],
#  [0.0, 'weekly_price - calculated_host_listings_count'],
#  [0.0, 'weekly_price - availability_90'],
#  [0.0, 'weekly_price - availability_60'],
#  [0.0, 'weekly_price - availability_365'],
#  [0.0, 'weekly_price - availability_30'],
#  [0.0, 'transit - zipcode'],
#  [0.0, 'transit - weekly_price'],
#  [0.0, 'transit - street'],
#  [0.0, 'transit - state'],
#  [0.0, 'transit - smart_location'],
#  [0.0, 'transit - security_deposit'],
#  [0.0, 'transit - room_type'],
#  [0.0, 'transit - reviews_per_month'],
#  [0.0, 'transit - review_scores_value'],
#  [0.0, 'transit - review_scores_rating'],
#  [0.0, 'transit - review_scores_location'],
#  [0.0, 'transit - review_scores_communication'],
#  [0.0, 'transit - review_scores_cleanliness'],
#  [0.0, 'transit - review_scores_checkin'],
#  [0.0, 'transit - review_scores_accuracy'],
#  [0.0, 'transit - require_guest_profile_picture'],
#  [0.0, 'transit - require_guest_phone_verification'],
#  [0.0, 'transit - property_type'],
#  [0.0, 'transit - price'],
#  [0.0, 'transit - picture_url'],
#  [0.0, 'transit - number_of_reviews_ltm'],
#  [0.0, 'transit - number_of_reviews'],
#  [0.0, 'transit - neighbourhood_group_cleansed'],
#  [0.0, 'transit - neighbourhood_cleansed'],
#  [0.0, 'transit - neighbourhood'],
#  [0.0, 'transit - monthly_price'],
#  [0.0, 'transit - minimum_nights_avg_ntm'],
#  [0.0, 'transit - minimum_nights'],
#  [0.0, 'transit - minimum_minimum_nights'],
#  [0.0, 'transit - minimum_maximum_nights'],
#  [0.0, 'transit - maximum_nights_avg_ntm'],
#  [0.0, 'transit - maximum_nights'],
#  [0.0, 'transit - maximum_minimum_nights'],
#  [0.0, 'transit - maximum_maximum_nights'],
#  [0.0, 'transit - market'],
#  [0.0, 'transit - longitude'],
#  [0.0, 'transit - license'],
#  [0.0, 'transit - latitude'],
#  [0.0, 'transit - last_review'],
#  [0.0, 'transit - is_location_exact'],
#  [0.0, 'transit - is_business_travel_ready'],
#  [0.0, 'transit - instant_bookable'],
#  [0.0, 'transit - host_verifications'],
#  [0.0, 'transit - host_url'],
#  [0.0, 'transit - host_thumbnail_url'],
#  [0.0, 'transit - host_since'],
#  [0.0, 'transit - host_response_time'],
#  [0.0, 'transit - host_response_rate'],
#  [0.0, 'transit - host_picture_url'],
#  [0.0, 'transit - host_neighbourhood'],
#  [0.0, 'transit - host_name'],
#  [0.0, 'transit - host_location'],
#  [0.0, 'transit - host_listings_count'],
#  [0.0, 'transit - host_is_superhost'],
#  [0.0, 'transit - host_identity_verified'],
#  [0.0, 'transit - host_id'],
#  [0.0, 'transit - host_has_profile_pic'],
#  [0.0, 'transit - guests_included'],
#  [0.0, 'transit - first_review'],
#  [0.0, 'transit - extra_people'],
#  [0.0, 'transit - country_code'],
#  [0.0, 'transit - country'],
#  [0.0, 'transit - cleaning_fee'],
#  [0.0, 'transit - city'],
#  [0.0, 'transit - cancellation_policy'],
#  [0.0, 'transit - calendar_updated'],
#  [0.0, 'transit - calculated_host_listings_count_shared_rooms'],
#  [0.0, 'transit - calculated_host_listings_count_private_rooms'],
#  [0.0, 'transit - calculated_host_listings_count_entire_homes'],
#  [0.0, 'transit - calculated_host_listings_count'],
#  [0.0, 'transit - beds'],
#  [0.0, 'transit - bedrooms'],
#  [0.0, 'transit - bed_type'],
#  [0.0, 'transit - bathrooms'],
#  [0.0, 'transit - availability_90'],
#  [0.0, 'transit - availability_60'],
#  [0.0, 'transit - availability_365'],
#  [0.0, 'transit - availability_30'],
#  [0.0, 'transit - amenities'],
#  [0.0, 'transit - accommodates'],
#  [0.0, 'summary - zipcode'],
#  [0.0, 'summary - weekly_price'],
#  [0.0, 'summary - street'],
#  [0.0, 'summary - state'],
#  [0.0, 'summary - smart_location'],
#  [0.0, 'summary - security_deposit'],
#  [0.0, 'summary - room_type'],
#  [0.0, 'summary - reviews_per_month'],
#  [0.0, 'summary - review_scores_value'],
#  [0.0, 'summary - review_scores_rating'],
#  [0.0, 'summary - review_scores_location'],
#  [0.0, 'summary - review_scores_communication'],
#  [0.0, 'summary - review_scores_cleanliness'],
#  [0.0, 'summary - review_scores_checkin'],
#  [0.0, 'summary - review_scores_accuracy'],
#  [0.0, 'summary - require_guest_profile_picture'],
#  [0.0, 'summary - require_guest_phone_verification'],
#  [0.0, 'summary - property_type'],
#  [0.0, 'summary - price'],
#  [0.0, 'summary - picture_url'],
#  [0.0, 'summary - number_of_reviews_ltm'],
#  [0.0, 'summary - number_of_reviews'],
#  [0.0, 'summary - neighbourhood_group_cleansed'],
#  [0.0, 'summary - neighbourhood_cleansed'],
#  [0.0, 'summary - neighbourhood'],
#  [0.0, 'summary - monthly_price'],
#  [0.0, 'summary - minimum_nights_avg_ntm'],
#  [0.0, 'summary - minimum_nights'],
#  [0.0, 'summary - minimum_minimum_nights'],
#  [0.0, 'summary - minimum_maximum_nights'],
#  [0.0, 'summary - maximum_nights_avg_ntm'],
#  [0.0, 'summary - maximum_nights'],
#  [0.0, 'summary - maximum_minimum_nights'],
#  [0.0, 'summary - maximum_maximum_nights'],
#  [0.0, 'summary - market'],
#  [0.0, 'summary - longitude'],
#  [0.0, 'summary - latitude'],
#  [0.0, 'summary - last_review'],
#  [0.0, 'summary - is_location_exact'],
#  [0.0, 'summary - is_business_travel_ready'],
#  [0.0, 'summary - instant_bookable'],
#  [0.0, 'summary - host_verifications'],
#  [0.0, 'summary - host_url'],
#  [0.0, 'summary - host_thumbnail_url'],
#  [0.0, 'summary - host_since'],
#  [0.0, 'summary - host_response_time'],
#  [0.0, 'summary - host_response_rate'],
#  [0.0, 'summary - host_picture_url'],
#  [0.0, 'summary - host_neighbourhood'],
#  [0.0, 'summary - host_name'],
#  [0.0, 'summary - host_location'],
#  [0.0, 'summary - host_listings_count'],
#  [0.0, 'summary - host_is_superhost'],
#  [0.0, 'summary - host_identity_verified'],
#  [0.0, 'summary - host_id'],
#  [0.0, 'summary - host_has_profile_pic'],
#  [0.0, 'summary - host_about'],
#  [0.0, 'summary - guests_included'],
#  [0.0, 'summary - first_review'],
#  [0.0, 'summary - extra_people'],
#  [0.0, 'summary - experiences_offered'],
#  [0.0, 'summary - country_code'],
#  [0.0, 'summary - country'],
#  [0.0, 'summary - cleaning_fee'],
#  [0.0, 'summary - city'],
#  [0.0, 'summary - cancellation_policy'],
#  [0.0, 'summary - calendar_updated'],
#  [0.0, 'summary - calculated_host_listings_count_shared_rooms'],
#  [0.0, 'summary - calculated_host_listings_count_private_rooms'],
#  [0.0, 'summary - calculated_host_listings_count_entire_homes'],
#  [0.0, 'summary - calculated_host_listings_count'],
#  [0.0, 'summary - beds'],
#  [0.0, 'summary - bedrooms'],
#  [0.0, 'summary - bed_type'],
#  [0.0, 'summary - bathrooms'],
#  [0.0, 'summary - availability_90'],
#  [0.0, 'summary - availability_60'],
#  [0.0, 'summary - availability_365'],
#  [0.0, 'summary - availability_30'],
#  [0.0, 'summary - amenities'],
#  [0.0, 'summary - accommodates'],
#  [0.0, 'street - zipcode'],
#  [0.0, 'street - weekly_price'],
#  [0.0, 'street - state'],
#  [0.0, 'street - security_deposit'],
#  [0.0, 'street - room_type'],
#  [0.0, 'street - reviews_per_month'],
#  [0.0, 'street - review_scores_value'],
#  [0.0, 'street - review_scores_rating'],
#  [0.0, 'street - review_scores_location'],
#  [0.0, 'street - review_scores_communication'],
#  [0.0, 'street - review_scores_cleanliness'],
#  [0.0, 'street - review_scores_checkin'],
#  [0.0, 'street - review_scores_accuracy'],
#  [0.0, 'street - require_guest_profile_picture'],
#  [0.0, 'street - require_guest_phone_verification'],
#  [0.0, 'street - property_type'],
#  [0.0, 'street - price'],
#  [0.0, 'street - number_of_reviews_ltm'],
#  [0.0, 'street - number_of_reviews'],
#  [0.0, 'street - neighbourhood_group_cleansed'],
#  [0.0, 'street - neighbourhood_cleansed'],
#  [0.0, 'street - neighbourhood'],
#  [0.0, 'street - monthly_price'],
#  [0.0, 'street - minimum_nights_avg_ntm'],
#  [0.0, 'street - minimum_nights'],
#  [0.0, 'street - minimum_minimum_nights'],
#  [0.0, 'street - minimum_maximum_nights'],
#  [0.0, 'street - maximum_nights_avg_ntm'],
#  [0.0, 'street - maximum_nights'],
#  [0.0, 'street - maximum_minimum_nights'],
#  [0.0, 'street - maximum_maximum_nights'],
#  [0.0, 'street - market'],
#  [0.0, 'street - longitude'],
#  [0.0, 'street - license'],
#  [0.0, 'street - latitude'],
#  [0.0, 'street - last_review'],
#  [0.0, 'street - is_location_exact'],
#  [0.0, 'street - is_business_travel_ready'],
#  [0.0, 'street - instant_bookable'],
#  [0.0, 'street - guests_included'],
#  [0.0, 'street - first_review'],
#  [0.0, 'street - extra_people'],
#  [0.0, 'street - country_code'],
#  [0.0, 'street - country'],
#  [0.0, 'street - cleaning_fee'],
#  [0.0, 'street - city'],
#  [0.0, 'street - cancellation_policy'],
#  [0.0, 'street - calendar_updated'],
#  [0.0, 'street - calculated_host_listings_count_shared_rooms'],
#  [0.0, 'street - calculated_host_listings_count_private_rooms'],
#  [0.0, 'street - calculated_host_listings_count_entire_homes'],
#  [0.0, 'street - calculated_host_listings_count'],
#  [0.0, 'street - beds'],
#  [0.0, 'street - bedrooms'],
#  [0.0, 'street - bed_type'],
#  [0.0, 'street - bathrooms'],
#  [0.0, 'street - availability_90'],
#  [0.0, 'street - availability_60'],
#  [0.0, 'street - availability_365'],
#  [0.0, 'street - availability_30'],
#  [0.0, 'street - amenities'],
#  [0.0, 'street - accommodates'],
#  [0.0, 'state - zipcode'],
#  [0.0, 'state - weekly_price'],
#  [0.0, 'state - smart_location'],
#  [0.0, 'state - security_deposit'],
#  [0.0, 'state - room_type'],
#  [0.0, 'state - reviews_per_month'],
#  [0.0, 'state - review_scores_value'],
#  [0.0, 'state - review_scores_rating'],
#  [0.0, 'state - review_scores_location'],
#  [0.0, 'state - review_scores_communication'],
#  [0.0, 'state - review_scores_cleanliness'],
#  [0.0, 'state - review_scores_checkin'],
#  [0.0, 'state - review_scores_accuracy'],
#  [0.0, 'state - require_guest_profile_picture'],
#  [0.0, 'state - require_guest_phone_verification'],
#  [0.0, 'state - property_type'],
#  [0.0, 'state - price'],
#  [0.0, 'state - number_of_reviews_ltm'],
#  [0.0, 'state - number_of_reviews'],
#  [0.0, 'state - monthly_price'],
#  [0.0, 'state - minimum_nights_avg_ntm'],
#  [0.0, 'state - minimum_nights'],
#  [0.0, 'state - minimum_minimum_nights'],
#  [0.0, 'state - minimum_maximum_nights'],
#  [0.0, 'state - maximum_nights_avg_ntm'],
#  [0.0, 'state - maximum_nights'],
#  [0.0, 'state - maximum_minimum_nights'],
#  [0.0, 'state - maximum_maximum_nights'],
#  [0.0, 'state - longitude'],
#  [0.0, 'state - license'],
#  [0.0, 'state - latitude'],
#  [0.0, 'state - last_review'],
#  [0.0, 'state - is_location_exact'],
#  [0.0, 'state - is_business_travel_ready'],
#  [0.0, 'state - instant_bookable'],
#  [0.0, 'state - guests_included'],
#  [0.0, 'state - first_review'],
#  [0.0, 'state - extra_people'],
#  [0.0, 'state - country_code'],
#  [0.0, 'state - cleaning_fee'],
#  [0.0, 'state - cancellation_policy'],
#  [0.0, 'state - calendar_updated'],
#  [0.0, 'state - calculated_host_listings_count_shared_rooms'],
#  [0.0, 'state - calculated_host_listings_count_private_rooms'],
#  [0.0, 'state - calculated_host_listings_count_entire_homes'],
#  [0.0, 'state - calculated_host_listings_count'],
#  [0.0, 'state - beds'],
#  [0.0, 'state - bedrooms'],
#  [0.0, 'state - bed_type'],
#  [0.0, 'state - bathrooms'],
#  [0.0, 'state - availability_90'],
#  [0.0, 'state - availability_60'],
#  [0.0, 'state - availability_365'],
#  [0.0, 'state - availability_30'],
#  [0.0, 'state - amenities'],
#  [0.0, 'state - accommodates'],
#  [0.0, 'space - zipcode'],
#  [0.0, 'space - weekly_price'],
#  [0.0, 'space - street'],
#  [0.0, 'space - state'],
#  [0.0, 'space - smart_location'],
#  [0.0, 'space - security_deposit'],
#  [0.0, 'space - room_type'],
#  [0.0, 'space - reviews_per_month'],
#  [0.0, 'space - review_scores_value'],
#  [0.0, 'space - review_scores_rating'],
#  ...]

# %%
listings.to_csv('listings-clean.csv', index = True)

# %%
listings.to_json('listings.json', orient = 'split', index = False)
